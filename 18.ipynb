# %% [markdown]
# # 5. 시스템분석 및 설계
# # 1.시스템개요
# 1.시스템정의
# 예정된 기능을 수행하기 위하여 설계된 상호 작용을 갖는 요소의 유기적 집합체
# 어떤 목적을 위하여 하나 잇아의 기능 요소가 상호 관련하여 유기적으로 결합
# 공통의 목적에 의하여 공통의 목적에 기여할수 잇는 많은 이질 부문으로 구성되는 복잡한 단일체
# <오답>상호 관련이 없는 구성 요소가 조합되어 어떤 목적을 위하여 유기적으로 결합
#
# 2. 시스템의 기본 5가지 요소
# 입력-출력-처리-피드백-제어
#
# 3.시스템의 기본 요소들이 각 과정을 올바르게 행하는지 감독하는 요소?제어
#
# 4. 시스템의 5대 기본 구성 요소의 설명
# 입력 기능은 처리 방법,제어조건,처리할 데이터를 시스템에 입력하는 기능
# 처리 기능은 결과를 산출하기 위해 입력 자료를 조건에 맞게 처리
# 제어기능은 각 과정에 제어기능이 올바로 수행되는지를 통제하거나 관리하는 기능
# <오답>유지 보수 기능은 시스템의 전반적인 기능들을 유지보수하는 기능
#
# 5. 시스템의 5가지 기본 요소중 아래 특징 갖는 것?
# “처리된 결과의 측정,분석 후 목표치 도달 여부 확인과 만족시럽지 못한 결과는 다시 조정하는 행위”    -> 피드백
#
# 6.시스템의 기본 요소 중 처리할 데이터 및 조건 부여하는 것? 입력
#
#
# 7.시스템 분석자와 설계자가 갖추어야 할 조건에 대한 설명
# 기업의 목적을 정확히 이해
# 업계의 동향 및 관계 법규 등도 파악
# 컴퓨터 기술과 관리 기법을 알아야한다
# <오답>현장 분석 경험은 중요하지 않다
#
# 8.일반적으로 시스템에 대한 정의는 여러 각도로 생각해 볼수 있다.
# 공동의 목표를 달성하기 위하여 함께 작용하는 상호 관련된 요소들의 집합
# 예정된 기능을 협동해서 수행하도록 설계된 상호 작용 요소들의 유기적인 집합체
# 규칙적으로 상호 작용하거나 상호 의존적이며 단일 집합을 형성하는 항목들의 집합
# <오답>추상적인 목표의 달성을 위하여 각 부분품들이 추상적인 동작을 수행하도록 하는 기능들의 집합체
#
# 9.시스템 분석가의 기본적인 조건
# 기업 목적의 정확환 이해
# 업무의 현장 분석능력
# 컴퓨터의 기술과 관리기법의 이해
# <오답>개인의 결단력과 추진력
#
# 10. 시스템 분석가로서 훌륭한 분석을 하기 위한 기본사항
# 분석가는 창조성
# 분석가는 시간배정과 계획 등을 빠른 시간 내에 파악
# 분석가는 컴퓨터장치와 소프트웨어에 대한 지식을 가져야 한다
# <오답> 분석가는 기계 중심적
#
#
# 11. 시스템이 구비해야 할 특성
# 목적성/자동성/제어성
# <오답>편리성
#
# 12. 시스템 개발 주기의 시스템 개발 단계 순서
# 시스템조사-시스템분석-시스템설계-시스템구현-테스트-유지보수
#
# 13.시스템 개발 단계중 가장 많은 비용이 투입되는 단계? 유지보수 단계
#
# 14.유지보수의 종류
# 수정/적응/예방
# <오답>순환
#
# 15.시스템 설계시 필요한 과정 나열 순서
# 목적설정-현장조사분석-신시스템설계-신시스템실행-신시스템실행후평가
#
# 16.시스템 개발 순서
# 예비조사-업무분석과요구정의-시스템설계-프로그램설계-프로그래밍-테스트와디버깅
#
# 17.시스템개발단계중 가장 마지막 단계
# 테스트와 디버깅ㅇㄴㄹ
#
# # 2.코드설계
# 1. 코드의 3대기능
# 식별/분류/배열
# <오답>정렬
# 2.코드설계 순서
# 대상선택-범위와기간설정-코드설계-코드표작성
#
# 3.코드설계시 유의사항
# 컴퓨터 처리에 적합
# 공통성
# 확장성
# <오답>다양성
#
# 4. 순서코드의 장점
# 확장성이 좋다
# 기억이 용이하다
# 단순하고 이해하기 쉽다
# <오답>누락된 번호를 삽입하기 쉽다
#
# 5. 주로 도서분류 코드에 사용되는 코드? 10진코드
#
# 6.코드화 대상 항목의 길이,넓이,부피,무게등을 나타내는 문자,숫자 혹은 기호를 그대로 코드로 사용하는 코드? 표의 숫자코드
#
# 7. 코드
# 냉장코 형광등 텔레비전   -> Mneminic code (연산코드)
#
# 8.코드의 기입 과정에서 원래는 1996으로 기입되어야 하는데 오기를 하여 1969로 표기됬을경우 어떤오류? Transcription Error (전위오류)
#
# 9. 코드34278을 34578과 같이 기록하는 것으로 디지트를 잘못 읽어 한 글자를 잘못 기록하는 오류? 필사오류
#
# 10.코드의 오류 발생 형태 중 좌우 자리가 바뀌어 발생하는 에러?transposition error
#
# 11. 코드설계순서
# 코드대상항목결정-사용범위와기간결정-코드화방식결정-코드의문서화
#
# 12.코드화 대상의 품목 명칭 일부를 약호 형태로 코드 속에 넣어 대상 항목을 쉽게 할 수 있는 코드? TV-C-19 : 19인치 컬러 텔레비전
# 연상코드
#
# # 3.입출력 설계
# 1.입력 정보 설계 순서
# 발생-수집-매체화-투입-내용
#
# 2.입력된 자료가 처리되어 일단 출력된 후 이용자를 거쳐 다시 입력되는 방식, 공과금,보험료 징수 등의 지로 용지를 처리하는데 사용되는 입력 방식? 턴 어라운드 시스템
#
# 3. 출력 정보의 설계 순서?
# 출력의내용-출력의매체화-출력의분배-출력의이용
#
# 4.출력매체 시스템   COM시스템
# -축소 보관과 반영구적인 매체로 사용가능
# -처리결과 마이크로필름기록
# -지도,설계도면
# 5. 출력설계 순서에서 제일 먼저 설계해야 하는 것?
# 출력정보의 내용에 관한 설계
#
# #  4. 파일설계
# 1. 전표처리에서 원장 또는 대장에 해당되는 파일로서 데이터 처리 시스템에서 중추적 역할을 담당하며 기본이 되는 데이터의 축적 파일? 마스터 파일
#
# 2. 마스터파일의 변경하고자 하는 내용을 검사하거나 갱신할 때 사용되는 정보,일시적인 성격?
# Transaction File
#
# 3. 길이가 같은 논리 레코드들이 같은 수로 모여 블록을 형성한 형식으로 모든 물리 레코드의 길이도 동일, 경제성이 높고 속도가 빠르며 프로그램 작성이 용이한 레코드 형식?
# 블록화 고정 길이 레코드
#
# 4. 경제성이 높고 속도가 빠르며, 프로그램 작성이 용이한 레코드 형식?
# 블록화 고정 길이 레코드
#
# 5.통계 처리나 파일의 자료에 잘못이 발생하였을 때 파일을 원상 복구하기 위해 사용되는 파일, 현재까지 변화된 정보를 포함하는 것으로 기록 파일? 히스토리 파일
#
# 6. 순차파일의 특징
# 처리하는데 불편이 많아 이용도가 낮다
# 데이터의 수록이 다른 파일에 비하여 어렵다
# 데이터 검색시 시간이 많이 걸린다
# <오답>파일의 내용을 추가,변경,삭제하기 매우 편리
#
# 7.색인순차 편성법
# 기본데이터구역,오버플로구역,인덱스구역으로 구성
# 순차 처리와 임의 처리가 가능하므로 목적에 따라 융통성 있게 처리
# 특정 레코드를 처리할 때 여러 단계의 인덱스 처리를 해야 하므로 접근 시간이 느리다
# <오답>자기 테이프,자기디스크,자기드럽등을기록 매체로 사용
#
# 8.입출력 파일 설계시 색인 순차 편성 파일 구성에서 새로이 추가되는 레코드가 많아서 기본 데이터 구역 내에 더 이상 기록할 수 없을 때, 오버플로된 레코드를 기록하는 구역?
# 실린더 오버플로 구역
#
# 9. 파일 편성법중 랜덤편성법
# 처리하고자 하는 레코드를 주소 계산에 의하여 직접 처리
# 어떤 레코드도 평균 액세스 타임으로 검색 가능
# 운영 체제에 따라서는 키 변환을 자동적으로 하는것도 있다
# <오답>키-주소 변환 방법에 의하여 충돌이 발생할 염려가 없으므로 이를 위한 기억 공간의 확보가 필요없다
#
# 10. 해싱에서 동일한 버킷 주소를 갖는 레코드들의 집합? Synonym
#
# 11.처리될 파일의 정보가 기록 순서나 코드 순서와 같은 논리적 순서와 관계 없이 특정한 방법으로 키 변환을 하여 임의로 자료를 보관하고 처리시에도 필요한 장소에 직접 접근하도록 만든 파일? 랜덤파일
#
# 12. 색인순차편성파일에 대한 특징
# 순차 처리와 임의처리 모두 가능
# 레코드의 추가 삭제시 파일 전체를 복사할 필요가 없다
# 오버플로우되는 레코드가 많아지면 사용 중에 파일을 재편성하는 문제점 발생
# <오답>어느 특정 레코드 접근시 인덱스에 의한 처리로 직접 편성 파일에 비해서 접근 시간 빠르다
#
# 13. 파일 설계의 순서
# 목적확인-항목검토-특성조사-매체검토-편성법검토
#
# 14.파일설계시 파일 성격에 관한 검토 사항
# 파일명칭,적용업무,작성목적
# <오답>항목배열
#
# 15.파일 매체의 설계 설명
# 어느 매체가 업무에 가장 적합한가를 충분히 검토하여 선정
# 매체 선정시 매체의 특성을 잘 이해하는 것이 좋다
# 매체 선정시 시간,용량,비용 검토
# <오답>파일 매체에 대한 검토는 액세스 형태만 충분히 검토
#
# # 5. 프로세스설계,처리패턴,오류체크
# 1.프로세스 설계시 유의해야 할 사항
# 신뢰성과 정확성을 고려하여 처리 과정을 명확히 표현
# 시스템의 상태 및 구성 요소,기능등을 종합적으로 표시
# 오루에 대비한 체크 시스템 고려
# <오답>사용자의 하드웨어와 프로그래밍에 관한 상식 수준고려
#
# 2.프로그래밍 지시서 포함
# PROGRAM-ID/입,출력일람,처리명세
# <오답>프로세스 흐름도
# 3. 입력 매체인 종이 테이프 또는 펀치 카드상의 데이터를 자기 디스크에 수록하는 처리는 프로세스의 표준 패턴중 어디? 매체변환
#
# 4.동일한 파일 형식을 가진 두개이상의 파일을 하나로 정리하는 처리 패턴,별도로 작성된 파일을 컴퓨터의 처리 효율이나 파일의 보관 등을 고려해서 하나의 파일로 통합하는 경우에 사용되는 처리 패턴? 병합
#
# 5.컴퓨터의 처리 효율이나 파일의 보관등을 고려하여 같은 파일 형식을 갖는 2개 이상의 파일을 하나의 파일로 통합 처리하는 것? 합병
#
# 6.마스터파일안의 정보 변동에 의해 추가,삭제,교환을 하고 새로운 내용의 마스터 파일을 작성하는것? 갱신
#
# 7.어떤 특정한 조건을 부여하여 조건을 만족시키는 정보와 만족시키지 못하는 정보로 분리하여 처리하는 패턴? 분배
#
# 8.입력자료의 어떤 항목 내용이 논리적으로 정해진 범위 내에 있는가를 체크?
# 유효범위체크
#
# 9.프로세스 입력 단계에서의 체크 중 입력 정보의 특정 항목 합계값을 미리 계산해서 이것을 입력 정보와 함께 입력하고, 컴퓨터상에서 계산한 결과와 수동 계산 결과가 같은지를 체크?
# 일괄합계체크
#
# 10.컴퓨터 입력 단계의 체크중 입력 정보의 두 가지 이상의 특정 항목의 합과 같다는 것을 알고 있을 때, 컴퓨터를 이용해서 계산한 결과와 분명히 같은 지를 체크? BalanceCheck
#
# 12.우리나라 주민등록번호의 코드 체크 방식? 체크디지트체크
#
# 13. 프로그램 설계서에 대한 설명
# 프로그램 설계서는 프로ㅓ그래머에게 주는 작업 지시서 역할
# 프로그램 설계서는 시스템 엔지니어 또는 시스템 분석가가 작성하는 것 원칙
# 프로그램 설계서에는 코드표,프로세스차트도 포함
# <오답> 프로그램 설계서는 프로그래머가 작성하기 때문에 개략적인 사항만 작성
#
# # 6. 평가,테스트,유지보수,문서화
# 1. 시스템 평가 목적
# 시스템 운영 관리 타당성파악/성능과유용도판단/처리비용과효율면개선점파악
# <오답>시스템 운영 요원 재훈련
#
# 2.시스템평가 항목의 요소
# 신뢰성/성능/기능
# <오답>가격
#
# 3.문서화 목적
# 개발후시스템 유지보수 용이
# 시스템 개발 중 추가 변경에 따른 혼란 방지
# 시스템의 개발 요령과 순서를 표준화하여 보다 효율적 작업 도모
# <오답>실수에 대한 책임의 명확화
#
# 5.시스템 판정기준
# 능력성/유연성/신뢰성
# <오답>추가성
#
#
# 6.기업의 측면에서 문서화를 통해 기대할 수 있는 효과와 가장 거리가 먼 것?
# 의사소통원활/생산성향상/정보축적
# <오답>시스템의 전체 개발 시간 단축
#
# 7.문서화
# 프로그램 내에도 문서화 할 수 있다
# 문서도 시스템 구성요소 하나
# 문서화는 시스템 개발 과정의 작업
# <오답>문서화는 시스템이 모두 개발된 후에 일괄적으로 작업해야 정확
#
# 8. 시스템 평가 목적
# 다른 시스템을 개발할 경우 똑 같은 오류가 발생 되는 것 방지 위함
# 시스템을 적절하게 운용하고 관리하는지 파악
# 시스템의 처리비용 및 처리의 효율성 개선
# <오답>새로운 프로그래밍 작성 기법을 개발하기 위함
#
# 9.시스템의 신뢰성 평가하는 MTBF의미?
# 상호 인접한 고장 사이의 가동된 시간 평균
#
# 10. 결합 테스트의 테스트 데이터 작성에 관한 설명
# 시스템의 단계별 기능을 테스트하는 것이므로 시스템 분석자가 작성하는 것이 바람직
#
# 11. 프로그램 단위별로 디버깅이 끝난 것을 모아 서로 연관된 프로그램군을 계통적으로 검사하는 테스트 방법? 결합테스트
#
#
# # 7. 구조적 개발 방법론
# 1.소프트웨어 생명 주기 모형 중 폭포수 모델 장점
# 적용사례가 많다
# 단계별 정의 분명
# 단계별 산출물 명확
# <오답>요구사항의 변경 용이
#
# 2.소프트웨어 수명 주기 모형 중 실제 상황이 나오기 전에 가상으로 시뮬레이션을 통하여 최종 결과물에 대한 예측 가능한 모형? 프로토타이핑모델
#
# 3.시스템 개발 주기를 폭포수형으로 표현할 때 순서
# 계획-요구사항정의-개략설계-상세설계-구현-시스템실행-유지보수
#
# 4.구조분석 특징
# 사용자와 분석자간의 의사 소통 원활
# 시스템 분석시 사용자의 참여 기회 확대
# 시스템 분할
# <오답>시스템 모형 작성에 필요한 도구가 제공되지 않는다
#
# 5.자료 흐름도 구성요소
# 프로세스/자료발생지/자료저장소
# <오답>자료사전
#
# 6.자료사전
# 시스템과 관련된 모든 자료의 명세와 자료 속성을 파악할 수 있도록 조직화한 도구
#
# 8. 자료사전 반복 기호 ? {}
#
# 9.DFD구성요소
# 자료흐름/처리/자료저장소
#
# 10. 구조적 프로그램 기본구조
# 순차,반복,조건
# <오답>일괄
#
# 11.모듈 틍징
# 서로결합되어 통속적으로 실행되지만 컴파일만큼은 독립적
# 업무성격이 비슷한 처리에 부품처럼 공통으로 사용
# 작성은 분담하여 도ㅓㄱ립적으로 작성
# <오답>모듈마다 사용할 변수를 새로 정의
#
# 12.N-S CHART설명
# 논리의 기술에 중점을 둔 도형식 표현 방법
# 연속 선택 및 다중 선택, 반복 등의 제어 논리 구조 표현
# 조건이 복합되어 있는 곳의 처리를 시각적으로 명확히 식별
# <오답>주로 화살표 사용하여 논리적인 제어 구조로 흐름을 표현
#
# 13.모듈의 독립성을 향상시키기 위한 결합도와 응집도?
# 결합도는 약하고 응집도는 강해야 한다
#
# 14.모듈 결합도가 높은 곳에서 낮은 순서
# 내용결합도-공통결합도-스탬프결합도-자료결합도
# 15.다른모듈내의 외부선언을 하지 않은 자료를 직접 참조,의존도가 대단히 높고 순서 변경이 다른 모듈에 영향을 주기 쉬운 모듈 결합도 해당? 내용결합
#
# 16.두모듈이 하나의 기억장소를 설정하여 그 기억장소에 데이터를 전달하면 다른 모듈이 그 기억 장소를 조회함으로써 정보 전달? 공통결합도
#
# 17.모듈의 결합도는 설계에 대한 품질 평가 방법의 하나로 두 모듈 간의 상호 의존도 측정. 품질이 가장 좋은 결합도? 자료 결합
#
# 18.구조적 프로그래밍 기법 설명
# 최초로 제창한 사람은 Dookstra
# 프로그램의 신뢰성과 생산성 향상 기할 수 있다
# 순차,선택,반복의 기본적 논리구조 갖는다
# <오답>GOTO명령을 사용하여 프로그램 이해 쉽다
#
# 19.프로그램 품질 개선과 생산성 향상을 위한 기법?IPT
#
# 20. IPT의 기술적인 측면
# 복합설계,구조적코딩,하향식프로그래밍
# <오답>상향식 프로그래밍
#
# 21.HIPO기법
# 체계화된문서작성/유지보수변경용이
# 도표상에 기능 위주로 입력내용,처리방법,출력 내용이 제시되므로 시스템 이해 쉽다
# <오답>상향식개발용이
#
# 22.HIPO패키지의 3단계 다이어그램
# Visual table of contents
# Overview
# Detail
# <오답>Table
#
# 23.HIPO 3단계 종류
# 도형목차,총괄도표,상세도표
# <오답>액션 다이어그램
#
# # 8. 객체지향 개발 방법론
# 1. 객체 설명
# 객체는 데이터 구조와 그 위에서 수행되는 함수들을 가지고 있는 소프트웨어 모듈
# 캡슐화와 데이터 추상화로 설명
# 데이터와 그 데이터를 조작하기 위한 연산 결합시킨 실체
# <오답>자신의 상태를 가지고 있고, 그 상태는 어떠한 경우에도 변하지 않는다
#
# 2.클래스 내에 속하는 객체들이 가지고 있는 데이터의 값들을 단위별로 정의하는 것으로서 성질,분류,식별,수량 또는 상태? 속성
#
# 3.객체의 외부적인 활동을 연산이라는 전제 하에서 구현한 것? 메소드
#
# 4.하나 이상의 유사한 객체들을 묶어서 하나의 공통된 특성 표현한 객체지향요소?클래스
#
# 5.객체지향 분석에서 불필요한 부분생략하고 객체의 속성중 가장 중요한 것에만 중점을 둔 개략개 시킨 것? 추상화
# 6. 객체지향 기법에서 데이터와 데이터를 조작하는 연산을 하나로 묶어 하나의 모듈 내에서 결합결합되 하는 것? 캡슐화
#
# 7. 자동차,말이라는 클래스에서 이동수단이라는 클래시 만드는 일?
# Abstraction
#
# 8.럼바우 객체지향 분석의 모델링 방법
# 동적/객체/기능
# <오답>클래스
#
# 9.하나 이상의 유사한 객체를 묶어서 하나의 공통된 특성을 표현한 것으로 데이터 추상화의 개념은? 클래스
#
# 10. 객체의 특성
# 상태화 행위를 가지고 있다
# 식별성 가진다
# 객체들 간의 관계를 가진다
# <오답>일정한 기억 장소를 갖지 않는다
