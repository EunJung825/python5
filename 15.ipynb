# %% [markdown]
# # 1강 데이터베이스 정의(24/29)
# 9.데이터 베이스 장점
# 많은 양의 종이파일이 감소화
# 정확한 최신의 정보이용 가능
# 데이터 처리속도 증가
# <오답>구축비용저렴
#
# 12. 데이터베이스 구성의 장점
# 데이터중복최소화
# 데이터공유
# 일관성유지
# <오답>데이터간의종속성유지
#
# 18.데이터베이스 서버의 선정시 직접적인 조건
# 고성능의 주기억장치와 빠른 입/출력 연산등이 수행될 수 있는 기능이 지원
# 다양한 사용자 인터페이스가 지원되어야 한다
# 대용량의 자료를 저장,탐색할 수 있으며 분산 데이터 관리가 지원되어야 한다
# <오답>응용프로그램 개발이 용이
#
# 23. 자료(data)와 정보(information)에 대한 설명
# 정보란 자료를 처리해서 얻을 수 있는 결과
#
# 24. 현실 세계로부터 단순한 관찰이나 측정을 통해 수집된 사실이나 값을 무엇이라 하는가
# 자료(data)
#
#
# # 2강 DBMS,스키마,DB언어,DBA    (51/73)
# 2.데이터베이스 관리 시스템의 주요 필수기능과 거리가 먼 것
# 정의기능/정확성과 안정서유지할수있는제어기능/조작기능
# <오답>데이터 사용자의 통제 및 보안기능
#
# 13.DBMS를 사용했을때의 장점
# 표준화의 범기관적시행
# 보안보장
# 무결성 및 일관성 유지
# <오답>단순한 예비와 회복기법
#
# 15.DBMS의 설명으로
# 종속성과 붕복성의 문제를 해결하기 위해서 제안된 시스템
# 응용프로그램과 데이터의 중재자로서 모든 응용 프로그램들이 데이터베이스를 공유할 수 있도록 관리
# 데이터베이스의 구성,접근방법,관리유지에 대한 모든 책임을 지고 있다.
# <오답>데이터 모델링을 수행하고 데이터베이스 스키마생성
#
# 24.스키마
# 현실세계의 특정한 한 부분의 표현으로서 특정 데이터 모델을 이용해서 만들어진다
# 시간에 따라 불변의 특성
# 데이터 구조적 특성을 의미하여 인스턴스에 의해 규정
# <오답> 한 조직에서 관심 있는 부분의 데이터 구조로 기술하는 언어 또는 그래프 표현의 집합
#
# 25. 3계층 스키마 중 개념 스키마 설명
# 한 기관 전체에서 필요로 하는 데이터베이스의 전체적인 논리적 구조
# 물리적 저장 장치의 입장에서 본 데이터베이스 구조
# 개체간의 관계와 유지해야할 제약 조건
# <오답>접근권한,부안정책,무결성규칙을맹세
#
# 30. 개념스키마
# 데이터베이스의 전체적인 논리적 설계를 의미하는 것으로 데이터 객체,성질,관계,제약조건에 관한 것
#
# 33. 데이터베이스 내용에 대한 전체적인 뷰(VIEW)라고 볼 수 있는 스키마
# 개념스키마
#
# 34. 논리적인 데이터베이스의 전체적인 구조를 나타내며,데이터베이스 파일에 저장되어 있는 레코드와 데이터 항복의 이름을 부여하고 그들 사이에 관계의 구조를 나타내는 스키마
# 개념스키마
#
# 37. 데이터베이스 설계에 적용되는 개념스키마 설명
# 데이터베이스에 대한 접근 권한이나 무결성 규칙에 대해서 기술한 것
#
# 39. 프로그래머 관접에서 데이터베이스를 바라볼 때 관심 있는 데이터 구조
# 외부스키마
#
# 40. 개념스키마
# 단순히 스키마
# 범기관적 입장에서 데이터베이스 정의
# 모든 응용시스템과 사용자가 필요로 하는 데이터를 통합한 조직 전체의 데이터베이스로 하나만 존재
# <오답>개개 사용자나 응용 프로그래머가 접근하는 데이터 베이스를 정의
#
# 42.스키마
# 스키마: 데이터베이스의 구조와 제약조건에 대한 명세를 기술
# 외부스키마:전체 데이터베이스의 한 논리적인 부분으로 볼 수 있으므로 서브스키마
# 개념스키마:데이터베이스 접근권한,보안정책,무결성규칙을 명세화
# <오답>  내브시키마:사용자나 응용 프로그래머가 접근할 수 있는 정의
#
#
#
# 47. 데이터베이스 관리자의 역할
# 데이터의 저장구조와 접근방법을 결정하는 역힐
# 시스템의 보안성과 무결성을 검사하는 기능 결정
# 데이터베이스에 대한 백업과 회복을 위한 적절한 방법 선택하는 역할
# <오답> 응용프로그램과 데이터베이스 사이에서 중재자로서의 역할 담당
#
# 48. 데이터베이스 관리자의 역할
# 데이터베이스 스키마 정의
# 데이터베이스 저장구조 및 접근 방법 정의
# 사용자들에게 데이터베이스의 접근 권한 부여
# <오답> 응용프로그램을 통하여 데이터베이스 접근
#
# 49. 데이터베이스 관리자 역할
# 개념 및 내부스키마 정의
# 변화 요구에 대한 적응과 성능 향상에 대한 감시
# 백업 및 회복 전략 정의
# <오답> 데이터베이스 자원 활용 및 사용자의 인터페이스 제공
#
# 51 데이터베이스 관리자 임무
# 개념 스키마 및 내부 시키마 정의
# 장애에 대비한 예비조치와 회복에 대한 전략 수립
# 접근 권한을 부여
# <오답> 데이터를 저장하고 저장된 데이터사용
#
#
#
# 52. 데이터베이스 관리자가 수행해야 하는 역할
# 시스템 감시 및 성능의 종합적인 분석과 성능의 개선
# 데이터의 접근 권한과 회복 절차 수립
# 데이터베이스의 구성요소 결정과 내장 저장구조 정의 및 수정
# <오답> 데이터베이스 조작어를 호스트 언어에 포함하여 데이터베이스 접근
#
# 53. DBA의 일반적은 기능에 대한 설명
# 계획-전체 조직의 사업 계획을 지원하는 데이터베이스 개발을 위한 전체적인 계획을 세운다.
# 설계- 현재 그리고 향후 필요로 하는 조직의 요구사항을 개념설계,논리설계,물리설계를 거쳐 데이터베이스화한다
# 확장 및 범용 데이터베이스의 성능 통제와 변경을 계획
# <오답> 구현-논리적으로 데이터베이스를 생성하고,업무에 필요한 응용 프로그램을 개발
#
# 63. 데이터 제어어(DCL)역할
# 불법적인 사용자로부터 데이터를 보호하기 위한 데이터보안
# 데이터 정확성을 위한 무결성
# 시스템 장애에 대비한 데이터 회복과 병행 수행
# <오답> 데이터의 검색,삽입,삭제,변경
#
# 70. 데이터 정의 언어(DDL)와 관련된 설명
# 데이터베이스 스킴은 데이터 정의 언어라는 특별한 언어로서 표현된 정의의 집합으로 지정
# DDL은 번역한 결과가 데이터사전 이라는 특별한 파일에 여러 개의 테이블로서 저장
# 데이터베이스 관리 시스템 내에서 사용자의 편의와 구현상의 편의를 위해 명령어를 제공하는것은DDL 이다
# <오답> 데이터 사전은 단순 데이터를 수용하고 있는 파일
#
# 73. 데이터베이스 스키마 설명
# 데이터베이스의 구조와 제약조건에 관한 전반적인 명세를 기술
# 외부스키마는 응용프로그래머가 데이터베이스를 바라보는 관점
# 개념스키마는 조직이나 기관의 총괄적 입장에서 본 데이터베이스의 전체적인 논리적 구조
# <오답>하나의 데이터베이스 시스템에는 내부,외부,개념 스키마가 각각 하나씩 존재
#
# # 3강. DB설계,데이터모델,ER모델 (42/65)
# 4. 데이터베이스 설계시 요구분석단계에서 나온 결과를 ER과 같은 DBMS에 독립적이고 고차원적인 표현기법으로 기술하는 것
# 개념스키마모델링
#
# 8. 데이터베이스 생명주기 단계중 목표 DBMS에 맞는 스키마를 정의하고 응용프로그램작성단계?
# 구현
#
# 9.서로다른 논리적스키마정의/정규화 과정을 이용한 릴레이션의 속성을 결정하는 단계
# 논리적설계단계
#
# 10. 데이터베이스 설계 단계중 논리적 설계 단계에 해당하는 것
# 목표 DBMS에 맞는 스키마 설계
#
# 12.물리적 데이터베이스 설계시 고려사항
# 파일과 구조 저장을 위한 최소한의 효율적 공간
# 트랜잭션 실행을 위한 시스템 내 입력부터 결과까지의 소요시간
# 단위시간당 처리 가능한 평균트랜잭션 수
# <오답>스키마의 모델링 작업과 요구되는 트랜잭션파악
#
# 17.DBMS DDL로 스키마를 작성하여 데이터베이스에 등록하고 응용프로그램을 위한 트랜잭션을 작성하는 단계? 구현
#
# 19.물리적 데이터베이스 구조에 대한 설명
# 데이터베이스 시스템의 성능에 중대한영향
# 여러 가지 타입의 저장 레코드 집합이라는 면에서 단순한 파일과 다르다
# 데이터베이스에 포함될 여러 파일 타입에 대한 저장레코드의 양식,순서,접근경로표현
# <오답> 기본적인 데이터 단위는 저장파일
#
# 20. 데이터 모델링의 과정을 올바른 순서
# 개체정의 – 식별자정의 – 상세화 – 통합 – 검증
#
# 22.데이터모델 설명
# 현실세계를 데이터베이스에 표현하는중간과정,데이터의 구조를 표현하기 위해 사용하는 도구
# 개념적데이터모델:속성들로 기술된 개체 타입과 이개체 타입들간의 관계를 이용하여 현실세계표현
# 논리적데이터모델:필드로 기술된 데이터 타입과 이 데이터 타입들간의 관계를 이용하여 현실 세계표현
# <오답> 현실세계를 데이터베이스로 표현하는 과정에서 개념적구조,논리적구조,물리적구조표현하기위해사용
#
# 27. 현실세계에 존재하는 개체를 인간이 이해할 수 있는 정보 구조로 표현하는 과정
# 정보모델링
#
# 32.데이터 모델의 구성요소
# 데이터 구조 및 정적 성질을 표현하는데 사용되는 구조
# 데이터의 인스턴스에 적용 가능한 연산 명세와 조작기법을 표현하는데 사용되는 연산
# 데이터의 논리적 제한 명시와 조작의 규칙이 되는 제약조건
# <오답> 데이터 개체집합 구성요소 사이의 대응성을 나타내는 관계
#
# 34. 개체에 대한 설명
# 실세계 존재
# 속성포함
# 구별가능
# <오답>관계에는 참여할수없다
#
# 35. 개체에 대한 설명
# 데이터베이스에 표현하려고 하는 현실세계의 대상체
# 유형,무형의 정보로서 서로 연관된 몇 개의 속성으로 구성
# 파일의 레코드에 대응하는것으로 어떤 정보를 제공하는 역할 수행
# <오답>속성들이 가질 수 있는 모든값들의 집합
#
# 36. 데이터모델중 성격이 같은 것
# 관계/계층/네트워크
# <오답>개체관계모델(ER)
#
# 38.ER모델설명
# 개체 타입과 이들 간의 관계 타입을 이용해서 현실세계를 개념적으로 표현
# 관계타입의 차원은 관계 타입과 관련된 엔티티 타입의 개수
# 관계 인스턴스는 다른 엔티티 타입에 속한 엔티티 사이의 관계 표현
# <오답>관계타입을 표현하는 방법은 그 관계타입의 이름과 함께 연관된 개체 타입들을 링크연결
#
#
# 41.ER모델
# 정보모델링을 통하여 얻어진 결과를 정보 구조화
# 정보구조를 구성하는 추상적 개념은 현실세계의 객체에서 추상화된 개체집합
# 각 개체 집합은 여러 개의 속성으로 표현,각속성은 현실 세계의 객체들이 갖는 특성
# <오답> 개념세계에서는 현실 세계에 대한 인식을 추상적 개념으로 표현하는데 이과정을 데이터 모델링이라한다
#
# 44. 개체 설명
# 컴퓨터가 취급하는 파일의 레코드에 대응
#
# 47.ER모델
# Peter chen에 의해 제안된 이래 개념적 설계에 가장 많이 사용되는 모델로서 일반적으로 쓰임
# 최초에는 entity,relationship,attribute와 같은 개념들로 구성되었으나 나중에 일반화 계층 같은 복잡한 개념들이 첨가되어 확장된 모델로 발전
# Attribute는 entity또는 relationship의 성질로 작은원으로 표시
# <오답> entity란 가상 세계의 객체를 나타낸다
#
# 57.데이터베이스의 구성요소중 데이터베이스가 표현하려고 하는 유형,무형의 정보대상으로 존재하면서 서로 구별될 수 있는 것? Entity
#
# 62. 개체 관계 모델
# 데이터를 엔티티,관계,속성으로 묘사
# ER모델에서 엔티티는 실세계에서 개념적 또는 물리적으로 존재하는 실제 사용의미
# ER모델에서 속성은 엔티티를 묘사하는데 사용될수 있는 특성 의미
# <오답> ER모델에서 관계는 속성들에 대한 관계표현
#
# 64.개체 집합 X와 Y가 있을 때, 구성되는 사상 원소수의 경우
# 일대일/일대다/다대다
# <오답> 다대일
#
# # 4강 논리적데이터모델,관계데이터모델 (36/59)
# 1.계층데이터 모델에서 두 레코드 간에 직업 표현 방법을 제공
# 1:1/!:N/두개의 1:N관계
# <오답> M:N
# 4.데이터모델에 관한 설명
# 관계데이터 모델은 개체와 관계모두가 테이블로 표현
# 계층 데이터베이스는 부자관계를 나타내는 트리구조
# 데이터모델은 데이터,데이터관계,데이터의 의미 및 일관성제약조건등을 기술하기 위한 개념적 도구모임
# <오답>네트워크데이터베이스는 오너-멤버관계를 나타내는 트리구조
#
# 10.데이터 모델 중에서 캡슐화,상속,다형성의 개념을 가지는 데이터 모델
# 객체지향 데이터 모델
#
# 11. 상위하나의레코드에 대하여 하위의 레코드가 복수대응,하위하나의레코드에대해서 상위레코드도 복수대응하는 데이터베이스 구조? 망구조
#
# 12.논리적 데이터 모델 설명
# 관계:테이블집합
# 네트워크:그래프구조
# 객체:객체/상속구조로 표현
# <오답>계층적 데이터 모델: 데이터베이스를 계층적 그래프 구조로 표현
# 13.네트워크 데이터 모델과 계층 데이터 모델의 공통적인 속성
# 개체의 표현방법/다대다 관계의 직접 표현 불가
#
# 18. 관계 데이터 베이스 모델에서 차수의 의미는? 애트리뷰트의수
#
# 19. 관계 모델에서 릴레이션이 가지는 성질
# 튜플의유일성/순서의무순서/튜플의무순서
# <오답>속성의복합값
# .
# 28. 릴레이션의 외연에 관련된 것? 릴레이션인스턴스
#
# 31.관계 데이터베이스를 구축할 때의 데이터 모델 개념
# 튜플:행
# 속성:개체가 가지고있는 성질
# 관계:개체간의 상호작용
# <오답> 도메인: 개체관계를 총칭하는 집합
#
# 38.릴레이션의 어트리뷰트의 개수:차수  / 릴래이션에 포함된 튜플의개수:카디널리티
#
# 39.릴레이션설명: 각 속성은 릴레이션 내에서 유일한 이름을 가진다
#
# 41.관계형데이터베이스에서 relation의 특성
# 튜플간에 순서가없다/속성간에 순서가없다
# 한 rerlation에 포함된 tuple들은 모두 상이하다
# <오답> 한 relation에 포함된 속성 값은 모두 상이
#
# 42.릴레이션 설명
# 릴레이션 스키마와 릴레이션 인스턴스로 구성
# 릴레이션 스키마는 한 릴레이션의 논리적 구조를 기술
# 릴레이션 스키마는 정적인 성질,인스턴스는 동적인 성질
# <오답> 릴레이션 인스턴스는 구조를,스키마는 실제값을 나타낸다
#
# 43. 키의 종류
# 후보키:개체들을 고유하게 식별할수있는속성
# 수퍼키:두개이상의 속성으로 구성된 기본키
# 외부키:다른테이블의 기본키로 사용
# <오답>보조키:후보키 중에서 대표로 선정된키
#
# 45.릴레이션r1의 애트리뷰트 A부르며, 관련된 제약조건은 무엇?
# 외래키/참조무결성제약
#
# 49. FK/R!/K
#
# 53. 개체 무결성 규칙
# 기본 relation에서 기본키의 어떤 성분도 NULL일수없다
#
# 54. 데이터베이스의 무결성
# 개체무결성 규정은 한 릴레이션의 기본키를 구성하는 어떠한 속성 값도 널값이나 중복 값을 가질수 없음을 규정
# 무결성의 규정에는 규정이름,검사시기,제약조건등을 명시
# 트리거는 트리거 조건이 만족되는 경우에 취해야하는 조치를 명세
# <오답>도메인 무결성 규정은 주어진 튜플의 값이 그 튜플이 정의된 도메인에 속한 값이어야 한다는 규칙 정하는 것
#
# 58.관계형 데이터 모델의 참조 무결성 제약
# 외래키의 속성들은 참조하려는 테이블의 기본키와 도메인 동일
# 외래키의 속성 개수와 참조하려는 테이블의 기본 키의 속성개수는 같아야한다
# 외래키값은 참조하려는 테이블의 기본키값으로 존재
# <오답> 외래키의 속성명과 참조하려는 테이블의 기본키의 속성명은 동일
