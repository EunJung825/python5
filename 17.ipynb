# %% [markdown]
# # 4. 정보통신개론
# # 1. 통신 개요 및 시스템 구성
# 1. 정보통신의미
# 컴퓨터와 통신 기술의 결합에 의해 통신 처리 기능과 정보 처리 기능은 물론 정보의 변환,저장 과정이 추가된 형태의 통신
#
# 2. 정보통신 설명
# 전기 통신과 컴퓨터의 정보 처리 능력을 부가시켜 정보를 송,수신처리하는 통신
# 컴퓨터나 통신 기기 사이에서 디지털 형태로 표현된 정보를 송,수신하는 통신
# 정보 처리 장치 등에 의하여 처리된 정보를 전송하는 기계 장치 간의 통신
# <오답> 전기적인 신호 형태의 디지털 데이터만 컴퓨터로 송,수신하는 통신
#
# 3. 정보 통신 시스템의 특징
# 통신 회선을 효율적으로 이용 가능
# 고성능의 에러 제어 방식을 사용하여 시스템 신뢰도가 높음
# 고품질의 통신 서비스 제공
# <오답> 협대역 전송에만 주로 사용
#
# 4. 통신 구성하는 요소
# 정보를 보내는 장소
# 전송매체
# 정보를 수신하는 장소
# <오답> 정보를 저장하는 장소
#
# 6.통신 제어 프로그램 기능
# 데이터 입,출력 제어 기능
# 데이터 버퍼링 기능
# 오류 처리 기능
# <오답> 전송하고자 하는 데이터 파일의 기밀 유지를 위한 암호화 기능
#
# 7. 꼬임선 특징
# 전기적 간섭 현상을 줄이기 위해서 균일하게 서로 감겨 잇는 형태의 케이블
# 하나의 케이블에 여러 쌍의 꼬임선들을 절연체로 피복하여 구성
# 가격이 저렴하고 설치가 간편한 이점
# <오답> 다른 전송 매체에 비해서 거리,대역폭 및 데이터 전송률 면에서 제한적이지 않다
#
# 8.광섬유 케이블 특징
# 전송 손실이 극히 적다
# 전기적으로 무유도성,무누화
# 광대역성
# <오답> 접속 및 확장이 불가능
#
# 9. 위성 통신 시스템의 구성요소
# 지구국,채널,통신위성
# <오답> 트랜스포터
#
# 10. 통신제어장치 설명
# 통신 회선의 전송 속도와 중앙 처리 장치의 처리 속도 사이에서 조정을 수행
#
# 11.”광섬유케이블” 전송매체 장점
# 고속의 데이터 전송과 대량의 데이터 전송 가능
# 크기가 작고 무게가 가볍다/ 가장적은 감쇠율
# 12. 위성통신의 다중접속 방법이 아닌 것
# 주파수분할 다중접속
# 시분할 다중접속
# 코드분할 다중접속
# <오답> 신호분할 다중접속
#
# 13. 광섬유에서 발생하는 손실
# 접속손실/마이크로벤딩손실/흡수손실
# <오답> 레일리분산손실
#
# 14. 정보통신의 발달에 큰 기여를 하였던 미국 항공 회사의 좌석 예약 시스템
# SABRE
#
#
# # 2. 통신용어
# 2.데이터 신호속도 단위? Bps
#
# 5.통신 회선의 전송 용량을 증가시키기 위한 방법
# 주파수 대역폭증가
#
# 10. 데이터 전송 속도의 척도
# 변조 속도
# 데이터 신호 속도
# 베어러 속도
# <오답> 반송파 주파수 속도
#
# 11. 대역폭 설명
# 최고 주파수와 최저 주파수 사이 간격을 의미
#
# 14. 통신용어
# 리피터-신호의 감쇠 현상을 복원해 주는 장치
# Modem-신호의 변복조 장치
# Bps-초당 전송 비트수
# <오답>baud- 초당 전송 바이트수
#
# 16.베어러 속도 단위? Bit/sec
#
# 18.변조속도
# 데이터 신호속도/변조시 상태변화수
#
# 19. 전송속도
# 보는 초당 발생한 신호의 변화 횟수
# Bps는 초당 전송된 비트수
# 변조속도의 단위로 보 사용
# <오답> 2비트가 한 신호단위인 경우 1200bps는 2400baud가 된다
#
# # 3. 전송방식과 신호변환
# 1. 디지털전송 전송 특징
# 전송용량을 다중화함으로써 효율성 높다
# 중계기를 사용함으로써 신호의 왜곡과 잡음 등을 줄일수 있다
# 디지털 기술의 발전으로 전송 장비의 소형화가 가능,가격도 저렴
# <오답> 암호화 작업이 불가능하므로 안정성 없다
# 2. 데이터 전송하는데 있어서 정보 전달 방향이 교대로 바뀌어 전송되는 통신
# 반이중 통신
#
# 3.전화와 같이 동시에 송신과 수신을 하는 전송 방식? 전이중 통신
#
# 4. 비동기 전송방식
# 스타트 비트와 스톱비트 사용
# 저속의 통신 시스템에 주로 사용
# 비트 열이 전송되지 않을 때 휴지 상태
# <오답> 송신 신호 클럭에 의해 타임 슬롯의 간격으로 비트를 식별
#
# 5. 전송 휴율이 좋고 주로 원거리 전송에 사용하며 정보의 프레임 구성에 따라 문자 동기 방식, 비트 동기 방식, 프레임 동기 방식으로 나누는 전송 방식? 동기식 전송
#
# 6. 아날로그 데이터를 전송하기 위해 디지털 형태로 변환시키고,이러한 디지털 형태를 원래의 아날로그 데이터로 복구 시키는 장치? 코덱
#
# 7.전송 회선 양단의 데이터 회선 종단 장치로서 단말에서 출력되는 디지털 신호를 디지털 전송에 적합한 신호 형식으로 변환 하거나 또는 그 반대의 동작을 하는 장치? DSU
#
# 8. DSU 설명
# 디지털 서비스 유니트 약자
# 직렬 유니폴라 신호를 변형된 바이폴라 신호로 바꿔준다
# 데이터 전송을 위해서 필요성이 증대
# <오답>모뎀이 송,수신단에 필요
#
# 9.동기식 변,복조기에서 주로 사용하는 변조 방식? 위상편이변조(PSK)
#
# 10. 일정 진폭 및 위상을 상호 변환하여 신호를 싣는 변조 방식?
# 진폭 위상 변조(QAM)
#
# 11. 반송파로 사용하는 정현파의 위상에 정보를 싣는 변조 방식으로, 일정 주파수와 진폭의 정현파 위상을 2등분,4등분,8등분 등으로 나누어 각각 다른 위상에 1,0을 할당하거나 두 비트 혹은 세 비트를 한꺼번에 할당 하는 디지털 데이터의 아날로그 부호화 방식? PSK
#
# 12. 디지털 데이터를 아날로그 신호로 변환하는 변조기법
# ASK / PSK / FSK
# <오답> PCM
#
# 13. PCM방식의 변조 순서
# 신호 – 표본화 – 양자화 – 부호화
#
# 16. PCM과정에 포함
# 샘플링 / 양자화 / 부호화
# <오답>다중화
#
# 17. 펄스 파형을 그대로 변조없이 전송하는 방식? 베이스밴드 전송
#
# 19. 모뎀의 기능
# 변조의 복조기능/ 펄스를 전송신호로 변환/ 데이터 통신
# <오답>라우팅
#
# 20. 아날로그-디지털부호화방법
# ASK/FSK/QAM
# <오답>CDM
#
# 21.디지털 전송 특징
# 신호에 포함된 잡음도 증폭기에서 같이 증폭되므로 왜곡 현상 심하다
# 아날로그 전송보다 훨씬 작은 대역폭 필요
# 아날로그 전송과 비교하여 유지비용 훨씬 더 요구
# <오답>장거리 전송시 데이터의 감쇠 및 왜곡 현상을 방지 하기 위해 리피터 사용
#
# 22. 베이스 밴드 전송 방식 사용되는 것? 펄스코드 변조
#
# 25. 비동기 전송 방식
# 수신기는 문자 단위의 재동기를 위해서 시작비트,정지비트 사용
# 비동기식 전송은 단순하여 저렴하게 구현,오버헤드 요구
# 정지비트는 휴지상태와 같으므로 송신기는 다음 문자를 보낼 준비가 될 때 까지 정지 비트를 계속 전송
# <오답>신호 내에 클록 정보를 포함하여 전송시키기 위해 맨체스터 부호화 방법 사용
#
# 26.PCM 방식에서 PAM 신호를 얻는 과정? 표번화
#
# 27.아날로그데이터를 디지털 신호로 변환하는 과정?
# Sampling표 / quantization(양)/ encoding(부)
# <오답>encryption 암호화
#
#
# # 4. 다중화기
# 1. 동기식 시분할기와 비동기식 시분할기의 특징
# 비동기식이 동기식에 비해 효율성 우수
# 비동기식 다중화기를 일명 통계적 다중화기,링크의 효율성 높인다
# 비동기식 다중화기는 데이터를 잠시 저장할 버퍼와 주소 제어 회로 등이 별도로 필요
# <오답>비동기식 다중화기는 데이터 전송 각 채널에 대한 고정된 슬롯이 설정
#
# 2. 역다중화기 특성
# 비용을 절감
# 광대역 통신 속도 얻을 수 있다
# 전용 회선의 고장시 DDD망 이용
# <오답>회선 경로 변경 어렵다
#
# 3. 집중화기 특징
# 입,출력 각각의 대역폭 다르다
# m개의 입력 회선을 n개의 출력 회선으로 집중화하는 장치
# 입력 회선의 수는 출력 회선의 수보다 같거나 많아야 한다
# <오답>구조가 복잡하면서 규칙적 전송 사용
#
# 4.주파수 분할 다중화기(FDM)에서 부채널 간의 상호 간섭을 방지하기 위한 지역?가드밴드
#
# 5. 통계적 시분할 다중화 기법 장점
# 낭비되는 슬롯을 전송하지 않기 때문에 채널의 낭비를 줄인다
# 동기식 다중화기보다 더 높은 전송 효율
# 같은 속도일 경우 동기식 다중화기보다 더 많은 수의 터미널을 접속
# <오답>각 터미널의 전송량과 관계없이 일정한 지연 시간을 가진다
# 6. 전송할 데이터가 없는 닫ㄴ말장치에도 타임슬롯을 할당하는 시분할 다중화(TDM)방식?
# 동기 시분할 멀티 플렉싱
#
# 7. 사용가능한 주파수 대역을 나누어서 통화로를 할당하는 방식?
# 주파수 부할 다중화
#
# 8. 여러 개의 채널들이 하나의 통신 회선을 통하여 결합된 신호의 형태로 전송되고 수신측에서 다시 이를 여러 개의 채널 신호로 분리하는 역할 수행하는 장비? 다중화 장비
#
# 9. 시분할 다중화기 중 종류가 다른 하나?
# 동기 시분할 다중화기
# <종류같은것>비동기/지능적/통계적시분할다중화기
#
# 10. 주파수 분할 다중화에 대한 설명
# 다중화하고자 하는 각 채널의 신호는 각기 다른 반송 주파수로 변조
# 부채널 간의 상호 간섭을 방지하기 위해 가드 밴드를 주어야 한다
# 전송매체에서 사용 가능한 주파수 대역이 전송하고자 하는 각 터미널의 신호대역보다 넓은 경우 적용
# <오답>동기식과 비동기식 다중화 반식
#
# 11. 전송 데이터가 있는 동안에만 시간 슬롯을 할당하는 다중화 방식? 통계적 시분할 다중화
#
# 12. 다중화 기법중 TV공중파 관련? FDM
#
# 13.지능 다중화기
# 실제 보낼 데이터가 있는 DTE에만 각 부채널에 시간폭 할당
# 주소,흐름,오류제어 등의 기능이 제공
# 실제 전소할 데이터가 있는 부 채널에만 시간폭을 할당, 많은 데이터 전송 가능
# <오답>가격이 싸고, 접속에 소요되는 시간이 길다
#
# 14. 다중화 방식 중 각 채널 할당 시간이 공백인 경우 다음 차례에 의한 연속 전송이 가능하여 전송 전달 시간을 빠르게 하는 방식? 비동기식 시분할다중화
#
# 15. 누화 및 상호변조잡음과 관계있는 멀티플랙싱? FDM
#
# # 5. 전송제어방식(회선제어,오류제어)
# 1. 전송제어 속하는 것
# 입,출력제어/동기제어/오류제어
# <오답>보완제어
#
# 2.정보의 전송 제어장치의 단계
# 회선접속-데이터링크의확립-데이터전송-데이터링크의해제통보-회선전달
#
# 3. 회선 제어 절차에 대한 설명
# 메시지전달-데이터를 수신측에 전송하며, 잡음에 의한 데이터의 오류 제어와 순서 제어를 수행하는 단계
#
# 4. 대표적인 문자 위주 프로토콜 BSC가 있다. 특징은?
# 에러 제어와 흐름 제어를 위해서는 정지-대기방식사용
# 점-대-점 링크뿐만아니라 멀티 포인트 링크에서도 사용
# 주로 동기식 전송 방식을 사용하나 비동기식 전송 방식을 사용
# <오답>전이중 전송만 지원
# 5.데이터 링크 제어 문자 중에서 수신측에서 송신측으로 부정읍답으로 보내는 문자?NAK
#
# 6.HDLC 설명
# 흐름 및 오류 제어를 위한 방식으로 ARQ사용
# 링크는 점대점,다중점 및 루프 형태로 구성
# 단방향,반이중,전이중 방식의 통신 방식 제공
# <오답>특정 문자 코드에 따라서 필드의 해석이 달라지므로 코드에 의존성 갖는다
#
# 7.HDLC프레임 구성 순서?
# 플래그 – 주소부 – 제어부 – 정보부 – 검사부 – 플래그
#
# 8. 프레임 동기 목적? 각통화로의 혼선방지
#
# 9. 송신 요구를 먼저 한 쪽이 송신권을 갖는 방식?Contention방식
#
# 10. 회선 경쟁 선택 방식?
# 회선에 접근하기 위해 서로 경쟁하는 방식
# 송신측이 전송할 메시지가 있을 경우 사용 가능한 회선이 있을 때 까지 기다린다
# ALOHA 방식이 대표적인 예
# <오답> 트래픽이 많은 멀티 포인트 회선 네트워크에서 효율적인 방식
#
# 11.멀티포인트방식에 있어서 중앙컴퓨터가 주변의 터미널로 데이터를 전송하고자 하는 경우, 수신측 터미널의 상태를 확인하는 절차는?Selection
#
# 12.데이터 통신에서 컴퓨터가 단말기에서 전송할 데이터의 유무를 묻는 것?Polling
#
# 13.HDLC 전송제어 절차에서 채용하고 있는 방식,데이터를 송신할 때 데이터 블록 구간을 플래그 순서로 식별하고 그림과 같은 형태로 플래그가 구성되는 동기 방식?프레임동기방식
#
# 14. 전송 제어의 단계 순서
# 회선의 접속-데이터링크설정-정보의전송-데이터링크해제-회선의절단
#
# 15. 전송방식(SYN / SYN / STX /TEXT /ETX)
# 문자 동기 방식
#
# 16. 프레임을 송신,수신하는 스테이션을 구별하기 위해 사용되는 스테이션 식별자 필드?
# 주소필드
#
# 17. 프로토콜방식 중 바이트 단위로 프레임을 구성하는 것?BSC방식
#
# 18. 서로 다른 주파수들이 똑 같은 전송 매체를 공유할 때 이 주파수들이 서로의 합과 차의 신호를 발생함으로써 발생되는 잡음? 상호 변조 잡음
#
# 19. 전송 채널 상에서 발생하는 왜곡중 채널 상에서 언제든지 발생할 수 있는 시스템적인 왜곡?
# 손실
#
# 20. 전진 에러 수정 방식에서 에러를 수정하기 위해 사용하는 방식?
# 해밍코드
#
# 21. 전송오류제어방식에서 오류 제어용 코드부가 방식
# 패리티검사/해밍코드사용방식/순환중복검사방식
# <오답>궤한 전송 방식과 연속 전송 방식
# 22.해밍거리
# 00011010   / 00000100
# 답)4
#
# 23. 수신 스테이션은 비트 에러나 프레임의 손실을 검사하게 되고 에러가 검출되면 자동적으로 송신 스테이션에게 재전송을 요청하는 자동 재전송을 하게 되는데 ARQ방식
# Go Back N ARQ /정지대기,선택적재전송ARQ
# <오답>슬라이딩윈도우
#
# 24. 특정 다항식에 의한 연산 결과를 데이터에 삽입하여 전송하는 에러검출 방법?CRC
#
# 25.홀수 패리티가 부가된 7비트 ASCII 코드 A(100 0001) 송신 데이터?
# 1000 0011
#
# 26. 자기 정정 부호의 하나로 비트 착오를 검출해서 1bit 착오를 정정하는 부호 방식?
# Hamming code
#
# 27.송신측은 하나의 블록을 전송한 후 수신 측에서 에러의 발생을 점검한 다음 에러 발생 유무 신호를 보내올 떄까지 기다리는 ARQ방식?
# Stop and wait ARQ
#
# 28.HDLC의 명령과 응답에 대한 프레임 종류
# Supervisory/ information/unnumbered
# <오답>Handle Frame
#
#
# 29. ARQ방식중 Go back N과 Selective Repeat ARQ에 대한 설명
#  Go back n은 오류 발생 이후의 모든 프레임을 재요청
# Selective repeat ARQ버퍼의 사용량이 상대적으로 크다
# Go back N은 프레임의 송신순서와 수신 순서가 동일해야 수신 가능
# <오답>selective repeat ARQ는 여러 개의 프레임을 묶어서 수신 확인
#
#
# # 6. 통신망의 분류
# 1. 전용회선 방식
# 직통회선/분기회선/직선분기회선
# <오답>교환회선
#
# 2.전용회선에 비해 공중 통신망의 장점
# 전송되는 전송량을 기준으로 볼 때 가격이 저렴
# 회선을 공유할 수 있으므로 효용도가 높아진다
# Back up을 사용자가 별도로 마련하지 않아도 된다
# <오답>사용방법이 간편하며 업무적용이 쉽다
#
# 3. 통신 회선 구성
# 멀티 드룹에 사용되는 터미널은 주소 판단 기능과 데이터 블록을 일시 저장할 수 있는 버퍼를 가지고 있어야 한다.
# 다중화 방식에서 통신 회선의 고장 시 고장 지점 이후의 터미널은 모두 운영 불능에 빠지는 단점
# 멀티 포인트 방식을 멀티 드룹 방식이라고도 한다.
# <오답>포인트 투 포인트 방식은 멀티 드룹 방식보다 모뎀의 시설수량을 줄일수있다
#
#
# # 7.교환기술
# 1. 서비스, 응답,경보 및 휴지 상태 복귀 신호 등의 기능을 수행하는 제어 신호?
# 감시제어신호
#
# 2. 시분할 교환 기술의 방식
# TDM버스 교환방식
# 타임 슬롯 교환 방식
# 시간 다중화 교환 방식
# <오답>메트릭스 방식
#
# 3. 공중 데이터 교환망 중 고정 대역폭을 사용하는 방식? 회선 교환
#
# 4. 음성 전화망과 같이 메시지가 전송되기 전에 발생지에서 목적지까지의 물리적 통신 회선 연결이 선행 되어야 하는 교환 방식? 회선교환방식
#
# 5. 메시지 교환의 특징
# 각 메시지마다 전송 경로가 다르다
# 네트워크에서 속도나 코드 변환이 가능
# 각 메시지마다 수신 주소를 붙여서 전송
# <오답>데이터의 전송 지연 시간이 매우 짧다
#
# 6. 패킷 교환망의 특징
# 전송량 제어와 전송 속도 변환
# 대량의 데이터 전송시 전송 지연
# 표준화 된 프로토콜 적용
# <오답>전송 오류의 정정 가능
# 7.패킷 교환망의 주요 기능
# 경로선택제어/트래픽제어/에러제어
# <오답>액세스 제어
#
# 8.데이터 전송 시에 일정 크게의 데이터 단위로 쪼개어 특정 경로의 설정 없이 전송되는 방식?
# 데이터그램 패킷 교환 방식
#
# 9.망구조의 기본유형
# 스타/링/트리
# <오답>십자형
#
# 10. 일반적으로 많은 단말기로부터 많은 양의 통신을 필요로 하는 경우에 유리한 네트워크 형태
# 망형
#
# 11.데이터를 설정된 통신 회선을 통하여 전송하는 방식으로서 정보량이 많을 때와 파일 전송 등의 긴 메시지 전송에 적합하여 정보 전송의 필요성이 생겼을 때 상대방을 호출하여 연결,이 물리적인 연결이 정보 전송이 종료될때까지 계속 유지되는 망? 회선 교환망
#
# 12. 하나의 메시지 단위로 축적 전달 방식에 의해 데이터를 교환? 메시지 교환방식
#
# 13. 패킷 교환 방식 특징
# Store and forward방식
# 융통성이 매우 큰 교환방식
# 패킷의 길이가 제한적인
# <오답>트래픽 량이 적은 경우에 적절
#
# 14. 패킷교환망의 특징
# 회선교환망보다 회선 이용률이 좋다
# 장애발생시 대체 경로 선택이 가능
# 전송량 제어와 전송속도의 변환이 가능
# <오답>대량의 데이터 전송시 전송지연이 적어진다
#
# 15. 통신경로가 설정되면 데이터의 형태,부호,전송제어 절차 등에 의한 제약을 받지 않는 교환방식? 회선교환방식
#
# #  8. 공유회선 점유방식,경로제어,트래픽제어
# 1 . 10 BASE T에서 10이 의미하는 것?
# 데이터 전송 속도가 10mbps이다.
#
# 2. 10BASE5 LAN에서 5가 나타내는 의미?
# 케이블의 길이는 최대 500 [m]
#
# 3. CSMA/CD 방식의 특징
# 통신량이 적을 때 채널 이용률이 낮다
# 장애 처리가 쉽다
# 일정 길이 이하의 데이터를 송신할 경우 충돌을 검출할 수 없다
# <오답>임의의 길이의 데이터를 안전하게 전달
#
# 4. 패킷 교환망의 주요 기능 중 하나는 이용자들의 패킷 통신을 위한 경로 배정이다. 패킷교환기에 들어가는 경로 배정 프로그램 작성 시 경로 배정 요소
# 성능/경로의 결정 시간과 장소/네트워크 정보 발생지
# <오답>프로그램 처리 속도
# 5. IP라우팅 프로토콜
# IGP / RIP / EGP
# <오답>HDLC
#
# 6.흐름 제어에서 한번에 여러 개의 프레임을 나누어 전송할 경우 효율적인 기법?
# 슬라이딩 윈도우
#
# 7.네트워크 내에서 패킷의 대기지연이 너무 높아지게 되어 트래픽이 붕괴되지 않도록 네트워크 측면에서 패킷의 흐름을 제어하는 트래픽 제어? 혼잡제어
#
# # 9.인터넷,통신망 네트워크 장비
# 1.정보통신 기술의 발전에 의해 출현한 정보화의 한 형태로서, 한 건물 또는 공장,학교,구내,연구소등의 일정 지역 내에서 설치된 통신망으로 각종 기기 사이의 통신을 실행하는 통신망?LAN
#
# 2.LAN의 기본적인 회선망의 형태
# 스타/버스/링형
# <오답>베이스밴드형
#
# 3. IEEE에 의한 LAN은 OSI 7계층 구조상 어느 부분에 위치?
# 물리 계층과 데이터 링크 계층
#
# 4. 대학,병원 및 연구소 등 근거리 통신망이 필요하면서도 여건이 안되는 기관 간에 인근 전화국의 데이터 교환망과 기존 통신망을 연동시켜 구성하는 통신망? CO-LAN
#
# 5. 다음중 매체로서 무선을 사용하는 LAN? IEEE802.11
#
# 6. 정보 제공시 통신 회선을 공중 통신 사업자로부터 임차하여 하나의 사설망을 구축하고 이를 통해 축적해 놓은 갖가지 정보를 유통시키는 정보 통신 서비스? VAN
#
# 7. 부가 가치 통신망의 기능?
# 교환,통신,정보처리 기능
# <오답>메시지 저장기능
#
# 8. ISDN설명
# ISDN의 채널은 B,D,E 등이 있다
# 동일한 통신망으로 음성이나 비음성 등의 통신 서비스 제공
# 통신망의 교환 접속 기능에는 회선 교환 방식과 패킷 교환방식
# <오답>256kbps 1회선 교환서비스가 기본
#
# 9. ISDN 베어러 서비스 해당? 회선교환
#
# 10. ISDN서비스중 실제로 단말을 조작하고 통신하는 이용자 측에서 본 서비스는?텔레서비스
#
# 11. 정보 통신망 상호간을 연견할 때 시설,운영 및 유지,보수의 책임 한계를 구분하기 위한 접속점을 무엇? 분계점
#
# 12. 광대역 ISDN 서비스의 특징으로 옳지 않은 것?
# 신호의 전송 속도가 매우 높다
# 서비스 신호 대역폭의 분포 범위가 넓다
# 연속성 신호와 군집성 신호가 공존
# <오답>서비스 시간의 범위가 좁다
#
# 13.웹 브라우저에서 지원하는 서비스
# 전자우편서비스/FTP서비스/HTTP서비스
# <오답>SNMP서비스
#
# 14. TCP/IP에 운용되는 응용 서비스
# FTP/Telnet/E-mail
# <오답> DSU
#
# 15.다른 네트워크 또는 같은 네트워크를 연결하여 그 중추 역할을 하는 네트워크로 보통 인터넷의 주가되는 기간망? Backbone
#
# 16.IP Address의 설명
# IP Address는 32bit크기로 8bit씩 4개의 필드로 분리 표기
# A등급인 경우 연결 가능 호스트 수는 256*256*256 이다
# c등급의 연결 가능 호스트 수는 256이다
# <오답>IP Address는 32bit로 표시되므로 총 32개 된다
#
# 17. IP주소에서 1개의 C class는 32비트의 길이로 8비트 호스트 식별자를 갖는다. 이때 최대 몇 개몇  호스트 주소 가질 수 있는가? 256
#
# 18. 프로토콜이 전혀 다른 네트워크 사이를 결합? 게이트웨이
#
# 19.TCP/IP 네트워크를 구성하기 위해 1개의 C클래스 주소를 할당 받았다. C클래스 주소를 이용하여 네트워크상의 호스트들에게 실제로 할당할 수 있는 최대 iP주소의 개수? 254
#
# 20. IP Address에서 네트워크 ID와 호스트 ID를 구별하는 방식? 서브넷마스크
# 22. 두개의 LAN이 데이터 링크 계층에서 서로 결합되어 잇는 경우에 이들을 연결하는 요소?
# 브리지
#
# 23. 두개의 서로 다른 형태의 네트워크를 상호 접속하는 3계층 장비? 라우터
#
# 24. ISDN 설명
# 음성 서비스를 포함한 광범위한 서비스를 제공
# 음성 신호와 컴퓨터 단말기에서 사용되는 신호, 텔레비전의 영상 신호 등을 하나의 통신망으로 연결 가능
# 데이터베이스나 정보 처리 기능의 이용 범위가 넓어지게 되어 통신의 이용 가치를 높이게 한다
# <오답>서로 다른 여러 서비스를 공유할 수 잇는 아날로그망
#
# 25.다음 설명 해당하는 것
# -제한된 지역 내의 통신/파일의 공용
# -공중망을 이용하는 광역통신망에 대조되는 통신망 / 소단위의 고속정보통신망
# 답 ) 거리통신망
#
# 26. LAN의 구성 형태와 매체접근제어 방식의 연결
# Star-회선교환
# Ring-토큰링
# Bus-CSMA/CD방식
# <오답> Mesh형- 레지스터 삽입방식
#
# 27. LAN의 매체 접근 제어중 토큰패싱 방식에 대한 설명
# 데이터 전송시 반드시 토큰을 취득,전송을 마친후에는 토큰을 반납
#
# 28. 인터네트워킹을 위한 장비
# Router/switch/bridge
# <오답>Firewall(방화병)
#
# 29. IP ADDRESS 설명
# 5개의 클래스 (a,b,c,d,e)로 분류
# A,B,C,클래스만이 네트워크 주소와 호스트 주소 체계의 구조를 가진다
# D클래스 주소는 멀티캐스팅을 사용하기 위해 예약
# <오답> E클래스는 특수 목적 주소로 공용으로 사용
#
# 30. ATM 셀의 헤더를 구성하는 필드애서 경로배정용 사용되는 것? VPI
#
# 31. ITU-T에서 권고한 B-SIDN ATM프로토콜 구조
# 사용자/제어/관리 평면
# <오답>통합 평면
#
# 32. IPv6 설명
# IPv6주소는 128비트 길이이다
# 암호호와 인증 옵션 기능 제공
# 프로토콜의 확장을 허용하도록 설계
# <오답>QOS는 일부 지원하지만, 품질 보장 곤란
#
# # 10. 프로토콜,뉴미디어,멀티미디어
# 1.프로토콜
# 정보 전송의 통신 규약
#
# 2. 프로토콜의 기본요소
# 구문/타이밍/의미
# <오답> 제어
#
# 3.프로토콜의 기능
# 동기제어/요약화/라우팅
# <오답>역다중화
#
# 4.OSI참조 모델 계층 구조로 최하위 계층부터 최상위 계층 순서
# 물리-데이터링크-네트워크-트랜스포트-세션-프리젠테이션-응용
#
# 5. OSI 7 계층과 이와 관련된 표준
# 물리계층 RS-232C
# 데이터링크 HDLC
# 네트워크 X.25
# <오답> 수송 ISDN
#
# 6.전송로 상에서 정보 전송을 담당하며, 오류 없이 정보를 전송하는 기능을 담당하는 프로토콜 계층? 데이터 링크 계층
#
# 7.패킷 정보를 전송하기 위하여 사용되는 계층? Network layer
#
# 8.OSI참조 모델의 계층에서 통신 시스템 간의 경로를 선택하는 기능,통신 트래픽의 흐름을 제어하는 기능 및 통신 중에 패킷의 분실로 재전송을 요청 할 수 있는 오류 제어 기능을 수행하는 것? 네트워크 계층
#
# 9. 통신 양단 간의 에러 제어와 흐름 제어 하는 계층? 트랜스포트 계층
#
# 10.OSI 7 계층 프로토콜로서,대화를 구성하고 동기를 취하여 데이터 교환을 관리하기 위한 수단을 제공하는 계층? 세션계층
#
# 11.공중데이터망에서의 패킷 형태를 위한 DTE와 DCE의 인터페이스 규격을 포함하고 있는 ITU-T권고안은? X.25
#
# 12. X.25는 ITU-T표준으로 호스트 시스템과 패킷 교환망 간 인터페이스를 규정. 이기능은?
# 물리/링크/패킷
# <오답> 전송
#
# 13. TCP/IP의 응용 프로토콜?
# Snmp/smtp /ftp
# <오답>ros
#
# 14.IP의 임무
# 호스트의 주소지정
# 패킷절단
# 전송 경로의 논리적 관리
# <오답>전송 패킷의 안정성
#
# 15. 인터넷 프로토콜 아키텍처를 구성하는 4계층?
# 전송,인터넷,링크계층
# <오답>표현계층
#
# 16.TCP/IP에서 네트워크계층과 관련
# Igmp/icmp/ip
# <오답>snmp
#
# 17.컴퓨터 통신에서 컴퓨터 상호 간 또는 컴퓨터와 단말기 간에 데이터를 송,수신하기 위한 통신 규약? 프로토콜
#
# 18. OSI-7layer 모델
# Application/datalink/network
# <오답>internet layer
#
# 19.OSI의 7계층 중 통신망의 연결을 수행하는 기능을 제공하며 ITU-T권고 x.25프로토콜의 대표적 계층? 네트워크
#
# 20.OSI창조모델 중 암호화,코드변환 및 압축 등을 수행하는 계층? 프리젠테이션 계층
#
# 21. 셀럴러 시스템 특징
# 가입자 용량을 극대화하기 위하여 주파수 재사용
# 통화 중인 가입자가 새로운 서비스 지역으로 진입할 때 통화의 단절 없이 계쏙 통화가 될 수 있게 한다
# 국가 간의 로밍 가능
# <오답>CDMA에서 셀 분할은 정적분할 방법만을 사용
#
# 22. 뉴미디어의 분류
# 방송계,통신계,패키지계
# <오답>전파통신
# 23.화상정보가 축적된 정보센터의 데이터베이스를 tv수신기와 공중전화망에 연결해서 이용자가 화면을 보면서 상호대화 형태로 각종 정보검색 활수 있는 뉴미디어?Videotex
#
# 24.통신과 방송이 결합한 위성 멀티미디어 환경에서 가장 각광받을 것으로 기대되는 미래의 이동통신 서비스? IMT-2000
#
# 25.이동통신 시스템에서 주로 이용하는 CDMA뜻?
# 코드분할 다중접속방식
#
# 26.비디오 텍스에서 문자정보와 도형정보가 여러색으로 표시. 도형정보의 표현형식
# Mosaic,geometric,photographic
# <오답>panorama방식
#
# 27.공동시청안테나를 이용하는 텔레비전방식으로 난시청 지역에 고감도 안테나를 설치, 수신한 양질의 tv신호를 일정한 전송로를 통하여 수요자에게 제공하는 뉴미디어? CATV
#
# 28. 패키지계 뉴미디어?
# VTR/비디오디스크/CD-Rom
# <오답>CATV
#
# 29. 뉴미디어 CATV설명
# 다채널로서 방송뿐만 아니라 정보통신서비스가 가능
# 원래 난시청 해소를 목적으로 설치했던 지역 공동 안테나 tv방식
# 전송로는 동축케이블이나 광섬유케이블 사용
# <오답>일반 지상파 tv방송과 컬러색상 구조 및 주사방식이 서로 다르다
#
# 30. 뉴미디어 특징
# 네트워크화,분산적,특정다수자
# <오답>단방향성
#
# 31. 통신 채널의 효육적 이용을 위해 사용되는 데이터 압축 방식?
# 허프만/LZW/MPEG
# <오답>해밍
#
# 32. 정보센터로부터 필요한 정보를 선택하여 공중전화망을 통해 일반 tv로 수신 가능한 뉴미디어?
# 비디오텍스
#
# 33. 멀티미디어의 표준화와 관련하여 MPGE란 다음중 무엇? 동화상 압축표준
#
# 34.tv신호의 주사선 틈을 이용해서 문자나 도형정보를 방송하고 시청자들이 단말기,어댑터 등의 장치를 이용해서 tv화면으로 그 내용을 시청할수 있도록 하는 서비스?텔리텍스트
#
# 35. 뉴미디어 특징
# 정보교환의 고속화와 대용량화
# 다채널성과 쌍방향성
# 정보형태의 다양화
# <오답>반도체와 아날로그 기술화
#
# 36. 전화와 텔레비전의 연결에 의한 정보 서비스의 형태? 비디오텍스
#
# 37. 쌍방향 통신이 있는 뉴미디어 해당? Videotex
