# %% [markdown]
# # 3.운영체제
# # 1.운영체제 개념
# 1. 운영체제목적
# 신뢰성향상/사용자 인터페이스제공/처리량향상
# <오답>
#
# 2.제어프로그램
# “작업의 연속 처리를 위한 스케줄 및 시스템 자원 할당 등 담당”
# 작업 제어 프로그램
#
# 3.제어프로그램
# Data management program
# Job control program
# Supervisor program
# <오답>Service Program
#
# 4.처리프로그램해당
# Language translate program/ service program/ problem program
#
# 5.운영체제위치
# 사용자-응용프로그램-유틸리티-하드웨어
# 유틸리디와 하드웨어 사이
#
# 6.운영체제설명
# 컴퓨터를 편리하게 사용하고 컴퓨터 하드웨어를 효율적으로 사용할수 있도록
# 스스로 어떤 유용한 기능도 수행하지 않고 다른 응용 프로그램이 유용한 작업을 할수 있도록 환경 마련
# 중앙처리 장치의 시간,메모리공간,파일,기억장치 등의 자원 관리
# <오답>컴퓨터 사용자와 컴퓨터 하드웨어간의 인터페이스로서 동작하는 일종의 하드웨어장치
#
# 7.운영체제 주된 관리 작업
# 기억장치관리,입.출력장치관리,프로세서 관리
# <오답>응용 프로그램 유지관리
#
# 8.운영체제의 성능 판단 요소
# 처리능력/신뢰도/사용가능도
# <오답>비용
#
# 9.운영체제목적
# 사용자의 인터페이스 제공
# 주변장치 관리
# 신뢰성 향상
# <오답>데이터 압축 및 복원
#
# 10. 운영체제의 운영 방식 설명
# 다중프로그래밍:하나의컴퓨터 시스템에서 여러 프로그램들이 같이 컴퓨터 시스템에 입력되어 주기억장치에 적대되고,이들이 처리장치를 번갈아 사용하며 실행하도록 하는 것
# 다중프로세싱:한대의 컴퓨터의 중앙처리장치가 2개 이상 설치 되어서 여러 명령을 동시에 처리
# 분산처리:여러대의 컴퓨터들에 의해 작업들을 나누어 처리하여 그 내용이나 결과를 통신망을 이용하여 상호 교환되도록 연결되어 있는 것
# <오답>한대의 컴퓨터를 동시에 여러 명의 사용자가 대화식으로 사용하는 방식으로 처리속도가 매우 빨라서 사용자는 독립적인 시스템을 사용하는 것으로 인식하는 것을 배치처리
# 11. 여러 명의 사용자가 사용하는 시스템에서 컴퓨터가 사용자들의 프로그램을 번갈아 가며 처리해 줌으로써 각 사용자들은 각자 독립된 컴퓨터를 사용하는 느낌 시스템?
# Time sharing system
#
# 12. 한정된 시간 제약조건에서 자료를 분석하여 처리하는 시스템으로 비행기 제어 시스템이나 교통제어등에 사용되는 운영체제? 실시간 시스템
#
# 13.시대적으로 가장 먼저 생겨난 방식? 일괄 처리 시스템
#
# 14. 운영체제의 발달 과정 순서
# 일괄처리-시분할-다중모드-분산
#
# 15.운영체제 설명
# 다중 사용자와 다중 응용 프로그램 환경 하에서 자원의 현재 상태를 파악하고, 자원 분배를 위한 스케줄링 담당
# Cpu,메모리공간,기억장치,입.출력장치등의 자원 관리
# 입.출력장치와 사용자 프로그램 제어
# <오답>운영체제 종류는 매크로프로세서,어셈블러,컴파일러
#
# 16.운영체제설명
# 운영체제는 컴퓨터 하드웨어가 사용자 간의 매개체 역할을 하는 시스템 프로그램
# 주목적은 컴퓨터 시스템을 편리하게 이용할 수 있게 하는데 있다
# 컴퓨터 시스템을 공정하고 효율적으로 운영하기 위해 어떻게 자원을 할당할 것인가 결정
# <오답>컴퓨터 시스템에 항상 존재해야 하며 컴파일러,문서편집기,데이터베이스 등의 프로그램을 반드시 포함하고 있어야한다.
#
#
# 17.운영체제 주요 역할 및 기능
# 컴퓨터 시스템에서의 오류 처리,사용자 간의 자원 스케줄링,입력 및 출력에 대한 보조적 기능제공
# <오답>고급 언어로 작성된 원시 프로그램 번역
#
# # 2.시스템소프트웨어 종류
# 1.compiler란?
# 원시 프로그램을 기계어로 바꾸는 sofrware이다
#
# 2.인터프리터 설명
# <오답>원시 프로그램의 각 문장을 즉시 번역해서 목적 프로그램 만들고, 이를 바로 실행
# 시분할 시스템 유용
# 원시 프로그램의 변화에 대한 반응이 빠르다
# CPU사용 시간의 낭비가 크다
#
# 3. compiler language나 assembly language로 작성된 프로그램을 지칭할떄?
# Source program
#
# 4. assembly 언어로 작성된 source program을 assembler를 이용하여 기계어로 번역하는 것?
# Assemble
#
# 5. 어셈블러를 두개의 pass로 구성하는 이유?
# 기호를 정의하기 전에 사용할 수 있어 프로그램 작성이 용이하기 때문에
#
# 6. 매크로 프로세서가 수행해야 하는 기본적인 기능?
# 호출인식,정의인식,정의저장
# <오답>매크로 구문인식
# 7.매크로 설명
# 매크로 라이브러리는 여러 프로그램에서 공통적으로 자주 사용되는 매크로들을 모아 놓은 라이브러리
# 매크로 프로서세의 수행 기능은 매크로 정의인식,정의저장,호출인식,확장 및 매개 변수 치환
# 매크로는 일종의 문자열 치환과 같이 사용된 횟수 만큼 명령어를 생성 삽입해서 실행
# <오답>매크로 정의 내에 또 다른 매크로를 정의할 수 없다
#
# 8. 부프로그램과 매크로의 공통점?
# 여러 번 중복되는 부분을 별로도 ㄹ작성하여 사용
#
# 9.로드 모듈 변환하는 것? Linkage Editor
#
# 10.로더 설명
# 재배치 로더는 단순한 로딩 외에 목적 프로그램의 재배치 담당
# 컴퓨터 내부로 정보를 들여오거나 또는 외부 기억장치로부터 정보들을 주기억장치 내에 적재하는 프로그램
# 동적 로더는 프로그램을 한꺼번에 적재하는 것이 아니라 실행 시 필요한 일부분만을 차례로 적재 하는 방식
# <오답>링킹-재배치-로딩-주기억장치 할당의 순서로 기능수행
#
# 11. 로더 기능
# Allocation할당/linking링킹/relocation재배치
# <오답>compile번역
#
# 12.일반적인 로더에 가장 가까운 것? Direct linking loader
#
# 13.절대로더에 할당 및 연결 작업의 수행 주체? 프로그래머
#
# 15. 시스템소프트웨어 중 나머지 셋과 성격이 다른 것
# 인터프리터,어셈블러,컴파일러
# <오답>로더
#
# # 3강.프로세스 개요
# 1.프로세스정의
# 실행적인프로그램
# 프로시저활동
# 운영체제가 관리하는 실행단위
# <오답>동기적 행위를 일으키는 주체/동시에 실행 될 수 있는 프로그램 집합
#
# 3.프로세스 제어 블록
# 프로세스에 할당된 자원에 대한 정보 갖고 있다
# 프로세스의 우선순위 정보
# 프로세스 현 상태
# <오답>부모 프로세스와 자식 프로세스는 pcb공유한다
#
# 4.pcb
# 프로세스상태,카운터,처리기 레지스터
# <오답>할당되지 않은 주변장치 상태 정보
#
# 5.실행중인 프로세스가 cpu할당시간을 다 사용한 후 어떤 상태로 전이?ready상태
#
#
# 6.실행중인 프로그램,프로시저가 활동 중인 것,비동기적 행위,pcb존재
# ->프로세스
#
# 7.컴퓨터 자체 내의 기계적인 장애나 오류로 인하여 발생하는 인터럽트? 기계검사
#
# 8.인터럽트의 종류 중 입/출력수행,기억장치할당,오퍼레이터와의 대화등을 위하여 발생하는 것?
# svc인터럽트
#
# 9.수행 중인 프로그램에서 0으로 나누는 연산이나 허용되지 않는 명령어의 수행,스택의 오버플로우등과 같은 잘못이 있을 때 발생하는 인터럽트? 프로그램검사인터럽트
#
# 10.스폴링?
# Simultaneous peripheral operation on – line 약자
# 어떤 작업의 입/출력과 다른 작업의 계산 병행 처리
# 다중 프로그래밍 시스템의 성능 향상
# <오답>주기억장치를 버퍼로 사용
#
# 11.프로세스?
# 실행 가능한 pcb가진 프로그램
# 프로세서가 할당하는 개체로서 디스패치가 가능한 단위
# 목적 또는 결과에 따라 발생되는 사건들 과정
# <오답>더 이상 계속할 수 없는 어떤 특정 사건을 기다리고 있는 상태
#
# 12.프로세스 설명
# 비동기적 행위를 일으키는 주체로 정의/실행중프로그램/프로세스각종자원요구
# <오답>트랩 오류,프로그램 요구,입.출력 인터럽트 대해 조치
# # 4.프로세스 스케줄링(비선점,선점)
# 1.스케줄링?
# 무한연기회피
# 단위 시간당 처리량 극대화
# 오버헤드 최소화
# <오답>모든 프로세스에게 공정하게 적용되어야 하기 때문에 우선순위 제도 불필요
#
# 2.가장 바람직한 스케줄링 정책?
# 응답 시간을 줄이고 cpu이용률 늘린다
#
# 3.스케줄링 목적
# 공평성유지,단위시간당 처리량최대화,응답시간빠르게
# <오답>운영체제의 오버헤드 최대화
#
# 4.선점스케줄링 방식
# 대화식 시분할 시스템 적합
# 긴급하고 높은 우선순위의 프로세스들이 빠르게 처리
# 선점을 위한 시간 배당에 대한 인터럽트용 타이버클록 필요
# <오답>cpu할당 받으면 다른 프로세스가 cpu를 강제적으로 빼앗을 수 없는 방식
#
# 5.중앙처리장치가 할당되는 프로세스 변경하기 위해 현재 중앙처리장치 사용하여 실행되고 있는 프로세스 상태 정보 저장,앞으로 실행될 프로세스의 상태 정보를 설정한 다음에 중앙처리장치를 할당하여 실행 되도록 하는 작업?context switchin
#
# 6.비선점 스케줄링 방식
# Fcfs,sjf
# 7.sjf스케줄링
# 작업이 끝나기까지의 실행 시간 추정치가 가장 작은 작업을 먼저 실행
# 평균 대기시간 최소화
# fifo보다 평균 대기시간이 작지만 긴 작업의 경우 fifo기법 보다 더 길고 예측 어렵다
# <오답>선점 스케줄링 기법해당
#
# 9.hrn스케줄링에서 우선순위 계산식
# (대기시간+서비스시간)/서비스시간
#
# 11.sjf방식의 단점을 보완하기 위해 대기시간을 고려한 프로세스의 응답률로 프로세스의 우선순위를 결정하는 프로세스 스케줄링 방법? hrn스케줄링
#
# 12. sjf 기법의 길고 짧은 작업 간의 불평등을 보완하기 위한 기법으로 대기 시간과 서비스 시간을 이용한 우선 순위 계산 공식으로 우선순위를 정하는 스케줄링?hrn
#
# 13.하나의 프로세스가 cpu할당 받아 실행하고 있을 때 우선 순위가 높은 다른 프로세스가 cup를 강제로 빼앗아 사용할 수 있는 선점형 스케줄링 기법? Srt
#
# 14.스케줄링 기법
# rr스케줄링은 주어진 시간 할당량안에 작업을 마치지 않으면 준비 완료 리스트의 가장 뒤로 배치
# hrn스케줄링은 그 작업이 서비스 받을 시간과 서비스를 기다린 시간으로 결정되는 우선순위에 따라 cpu할당
# 기한부 스케줄링은 제한된 시간 내에 반드시 작업이 완료 되도록 스케줄링 하는 기법
# <오답>sjf스케줄링은 남아 있는 실행 시간의 추정치가 작은 작업 먼저 실행,언제라도 실행 중인 작업이 강제로 실행 멈출수있는 선점기법
#
#
# 15.스케줄링 기법중 sjf기법과 srt기법에 설명
# Sjf는 비선점기법
# Sjf는 작업이 끝나기까지의 실행 시간 추정치가 가장 작은 작업 먼저 실행
# Srt는 시분할 시스템 유용
# <오답>srt에서는 한 작업이 실행을 시작하면 강제로 실행 멈출 수 없다
#
# 16.프로세서 스케줄링 기법중 round robin기법 설명
# 시간 할당량이 너무 커지면,fcfs와 비슷
# 시간 할당량이 너무 작아지면, 오버헤드가 커지게 된다
# interactive시스템 많이 사용
# <오답>비선점형 기법
#
# 17. 라운드 로빈 스케줄링 방법
# 시간 분할의 크기가 작으면 작은 프로세스들에게 유리
# 시간분할의 크기가 너무 작으면 스레싱에 소요되는 시간의 비중이 커진다
# 시간분할의 크기가 커지만 fcfs방법과 같게 된다
# <오답>비선점 기법
#
# # 5.병행프로세스와 교착상태
# 1.다중 프로그래밍 운영체제에서 한 순간에 여러 개의 프로세스에 의히여 공유되는 데이터 및 자원에 대하여,한순간에는 반드시 하나의 프로세스에 의해서만 자원 또는 데이터 사용,자원이 프로세스에 의하여 반납된 후 비로서 다른 프로세스에서 자원을 이용하거나 데이터를 접근할 수 있도록 지정된 영역?criticalsection
#
# 2.한프로세스가 공유 메모리 혹은 공유 파일을 사용하고 있을 때 다른 프로세스들이 사용하지 못하도록 배제시키는 제어 기법? Mutual exclusion
#
# 3.세마포어 설명
# Dijkstra가 제시한 상호 배제 알고리즘
# v조작은 블록 큐에 대기 중인 프로세스를 깨우는 신호,흔히signal동작
# p조작은 임계 영역을 사용하려는 프로세스들의 진입 여부를 결정하는 조작,wait동작
# <오답>세마포어 변수는 양의 정수 값만을 가질 수 있다
#
# 4.모니터 설명
# 모니터의 경계에서 상호 배제 시행
# 자료 추상화와 정보 은폐 기법 기초
# 순차적으로 재사용 가능한 특정 공유 자원,공유자원그룹을 할당 하는데 필요한 데이터 및 프로시저를 포함하는 병행성 구조
# <오답>모니터 내의 데이터는 모니터 외부에서도 액세스할수있다
#
# 5.교착 상태 발생의 필요조건
# 점유와대기,비선점,환형대기
# <오답>상호종속
#
# 6.교착 상태는 순환대기 상황을 허용하지 않음으로써 해결할수있다
# 모든 자원들을 선형순서로 분류
# 프로세스는 자신이 가지고 있는 자원보다 앞의 순서에 있는 자원들만 요청
# 프로세스는 자신이 가지고 있는 자원보다 뒤의 순서에 있는 자원들만 요청
# <오답>프로세스는 자신이 가지고 있는 자원의 앞 또는 뒤의 순서에 있는 자원들을 자유롭게 요청
#
# 7.교착 상태의 예방 기법 중 각 프로세스는 한꺼번에 자기에게 필요한 자원을 모두 요구,이 요구가 만족되지 않으면 작업을 진행할 수 없게 하는 방법. 무슨 조건 방지? 점유및대기
# 8. 교착상태
# 교착 상태의 예방은 자원의 이용율이 낮아지지만 널리 사용되는 방법
# 교착 상태의 예방은 가장 명료한 해결책이나 프로세스가 실행하기 전에 모든 자원을 배당시키는 등 엄격한 자원 배당과 해제 정책 사용
# 교착 상태 예방은 상호배제,점유및대기,비선점,환형대기중 어느 하나를 발생하지 않게 함으로써 예방
# <오답>교착상태의 예빵은 시스템의 운영 중 상황을 보아가면서 교착 상태 가능성을 피해가는 것
#
# 9.은행가 알고리즘은 다음 교착 상태 관련 연구 분야중 어느 분야? 교착상태의회피
#
# 10. 교착 상태 설명
# 교착상태 발생의 필요 충분조건은 상호배제,점유및대기,환형대기,비선점조건
# 교착상태의 회피는 교착상태에 빠질 가능성을 인정하고 적절히 이를 피해가는 방법
# 교착상태의 회복은 교착상태에 빠져 있는 프로세스를 중지시켜 시스템이 정상적으로 동작 할 수 있도록 하는 방법
# <오답>교착상태란 두개 이상의 프로세스들이 자원을 점유한 상태에서 서로 다른 프로세스가 점유하고 있는 자원을 동시에 사용할 수 있는 현상 의미
#
# 11. 여러 개의 병렬 프로세스가 공통의 변수 또는 자원에 접근할 때, 그 조작을 정당하게 실행하기 위하여 접근 중인 임의의 시점에서 하나의 프로세스만이 그 접근을 허용하도록 제어하는 것?
# 상호배제
#
# 12. 교착상태와 은행원 알고리즘의 불안전 상태의 대한 설명
# 교착상태는 불안전 상태에 속한다
#
#
#
# 13.임계구역 설명
# 임계 구역에서 프로세스 수행은 가능한 빨리 끝내야 한다
# 임계 구역에서는 프로세스가 무한 루프에 빠지지 않도록
# 임계 구역에서는 프로세스들이 하나씩 순차적으로 처리
# <오답> 프로세스가 일정 시간 동안 자주 참조하는 페이지의 집합
#
# 14.교착상태가 발생하려면 4가지 필요충분 조건들이 충족,조건에 대한 설명
# 점유및대기:최소한 하나의 자원을 점유하고 있는 프로세스가 있어야 하며, 이 프로세스가 다른 프로세스에 의하여 점유된 자원을 추가로 얻기 위해 대기하고 있어야 한다
# 비선점:자원들을 선점하지 못한다
# 순환대기:대기하고 있는 프로세스의 집합 p0,p1,pn에서 p0은 p1이 점유한 자원을 대기하고 있고, p1은 p2를 대기하며 pn은p0가점유한 자원을 요청하기 위해 대기
# <오답>상호배제:최소한 하나의 자원이 공유 방식으로 점유
#
# # 6.기억장치 관리기법(주,가상)
# 1.새로 들어온 프로그램과 데이터를 주기억장치 내의 어디에 놓을 것인가를 결정하기 위한 주기억장치 배치 전략?
# Best fit/worst fit/first fit
# <오답>last fit
#
# 3.저장장치의 배치 전략 중에서 작업의 배치 결정을 가장 빨리 내릴수 있는?firstfit
#
# 4.설명이 의미하는 것
# 단일사용자 시스템에서 프로그램의 크기는 주거억 장치의 용량보다 클 수는 없다
# 사용하지 않는 프로그램의 부분을 보조기억장치로 옮겨와서 이제 더 이상 필요하지 않는 프로그램 부분이 사용하고 있떤 장소를 다른 프로그램이 사용하게 하면 실제 영역보다 더 큰 프로그램 실행 가능  ->오버레이
# 6.주기억장치상에서 빈번하게 기억 장소가 할당되고 반납됨에 따라 기억 장소들이 조각들로 나우어지는 현상? Fragmentation
#
# 7.메모리 관리 기법 중에서 서로 떨어져 있는 여러 개의 낭비 공간을 모아서 하나의 큰 기억 공간을 만드는 작업? Compaction
#
# 9.가상기억장치 설명
# 연속 배당 방식에서의 기억 장소 단편화 문제를 적극적으로 해결
# 기억 장치의 이용률과 다중 프로그래밍의 효율 높일 수 있다
# 가상 기억장치의 일반적인 구현 방법에는 페이징기법,세그먼테이션기법
# <오답>주기억장소의 물리적 공간보다 큰 프로그램은 실행 될 수 없다
#
# 10.기억장치 관리 기법 중 세그먼트 기법 사용하는 기억장소 보호 방법?기억장치보호키
#
# 11.가상 기억장치에서 주기억장치로 페이지를 옮겨 넣을 때 주소를 조정해 주어야 하는데 이를 무엇이라 하는가? 매핑
#
# 12.세그먼테이션 기법 설명
# 외부 단편화 발생
#
# 13.시간적 구역성의 예
# 루프/서브루틴/스택
# <오답>프로그램의 순차적수행
#
# 14.스레싱현상의 해결조치
# 부족한자원증설/일부 프로세스중단
# 성능자료의 지속적 관리 및 분석으로 임계치를 예상하여 운영
# <오답>다중프로그래밍정도높여준다
#
# 15.구역성
# 프로세스가 실행되는 동안 일부 페이지만 집중적으로 참조되는 경향
# 시간 구역성은 최근에 참조된 기억 장소가 가까운 장래에도 계속 참조될 가능성이 높음
# 공간 구역성은 하나의 기억 장소가 참조되면 그 근처의 기억 장소가 계속 참조되는경향
# <오답>프로세스가 효율적으로 실행되기 위해 프로세스에 의해 자주 참조되는 페이지들의 집합
#
# 16.denning이 제안한 프로그램의 움직임에 관한 모델로 프로세스를 효과적으로 실행하기 위하여 주기억장치에 유지되어야 하는 페이지들의 집합? Working set
#
# 17.페이지크게 설명
# 페이지 크기가 작을경우,페이지 단편화를 감소시키고 특정한 참조 지역성만을 포함하기 때문에 기억장치 효율은 좋을 수 있다
#
# 18.하나의 프로세스가 작업 수행 과정에서 수행하는 기억 장치 접근에서 지나치게 페이지 폴트가 발생하여 프로세스 수행에 소요되는 시간보다 페이지 이동에 소요되는 시간이 더 커지는 현상? 스레싱
#
# # 7.페이지 교체 알고리즘
# 1.기억장치 관리의 페이지 교체 기법
# Lfu/fifo/lru
# <오답>sjf
#
# 2.nur기법은 호출 비트와 변형 비트를 가진다, 가장 나중에 교체될 페이지?
# 호출비트:1,변형비트:1
# 3.요구 페이징 기법중 가장 오랫동안 사용되지 않았던 페이지를 먼저 교체하는 기법? LRU
#
# 4.NUR페이지 교체 방법에서 가장 우선적으로 교체 대상이 되는 것?
# 참조도 안되고 변형도 안된 페이지
#
# 5.페이지교체 알고리즘 중에서 각 페이지들이 얼마나 자주 사용 되었는가에 중점을 두어 참조된 횟수가 가장 적은 페이지를 교체?LFU
#
# 6.LRU기법을 이용하여 페이지 교체 기법을 사용하는 시스템에서 새로운 페이지를 적재하고자 한다. 어떤 페이지 교체? 가장 오랫동안 참조되지 않은 페이지 교체
#
# # 8.디스크 스케줄링
# 1.디스크 스케줄링 기법중에서 탐색 거리가 가장 짧은 요청이 먼저 서비스를 받는 기법,탐색 패턴이 편중되어 안쪽이나 바깥족 트랙이 가운데 트랙 보다 서비스를 덜 받는 경향이 있는 기법?SSTF
#
# 3. 디스크 스케줄링 기법 중 항상 바깥쪽 실린더에서 안쪽으로 움직이면서 가장 짧은 탐색 시간을 가지는 요청을 서비스 하는 기법?C-Scan
#
# 4.디스크 스케줄링 기법중 특징
# “디스크의 헤드가 제일 바깥 트랙에서부터 시작하여 제일 안쪽트랙으로 이동하면서 요구에 대한 서비스를 수행하는 기법으로 안쪽 실린더 도착 시 다시 바깥쪽 실린더 쪽으로 헤드가 이동하면서 수행되는 서비스”   - > C-Scan
#
# 6.디스크스케쥴링 정책
# “현재 위치로부터 탐색 거리가 가장짧은 트랙에 요청 먼저 서비스,디스크 요청이 특정 트랙 근처에 몰릴 경우 먼 거리의 트랙에 대한 서비스는 매우 오래 기다리게 되는 기아 상태 발생,처리량이 많은 일괄처리 시스템 유용”
# SSTF
# # 9.파일관리
# 1.파일 시스템 기능
# 파일의 생성,변경,제거
# 파일에 대한 여러 가지 접근 제어 방법 제공
# 정보 손실이나 파괴를 방지하기 위한 기능
# <오답>고급 언어로 작성된 원시 프로그램 번역
#
# 2.파일 디스크립터의 내용
# 보조기억장치의 유형.파일의구조,접근제어정보
# <오답>오류 발생시 처리방법
#
# 3.순차파일
# 적합한 기억 매체로는 자기 테이프를 쓰면 편리
# 기억장치 효율 높다, 검색시 효율나쁘다
# <오답>필요한 레코드를 삽입하는 경우 파일 전체를 복사할 필요가 없다
#
# 4. 파일의 접근 방식
# 직접 접근 파일에서 파일을 구성하는 어떠한 블록도 직접 접근할 수 있어서 판독이나 기록의 순서에는 제약이 없다
#
# 5. 특정 레코드를 검색하기 위하여 키와 보조기억 장치 사이의 물리적인 주소로 변환할 수 잇는 사상 함수가 필요한 파일?? 직접파일
#
# 6. 직접파일 설명
# 직접 접근 기억장치의 물리적 주소 통해 직접 레코드 접근
# 키에 일정한 함수를 적용하여 상대 레코드 주소를 얻고,그 주소에 레코드를 저정하는 파일 구조
# 직접 접근 기억장치의 물리적 구조에 대한 지식 필요
# <오답>직접 파일에 적합한 장치로는 자기 테이프를 주로 사용
#
# 7.파일 구성 방식중 indexed sequential access방식 특징
# 각 레코드는 레코드 키 값에 따라 논리적 배열
# 시스템은 각 레코드의 실제 주소가 저장된 인덱스 관리
# 일반적으로 디스크 기억장치에 많이 이용
# <오답>레코드가 직접 액세스 기억장치의 물리적 주소를 통하여 직접 액세스 된다
#
# 8. 파일 시스템의 디렉토리 중 가장 간단한 디렉토리 구조로서 모든 파일들이 유일한 이름을 가지고 있고 같은 디렉토리 내에 위치하여 관리되는 디렉토리 구조?1단계디렉토리구조
#
# 9.파일 시스템에서의 일반적인 디렉토리 구성 방식?
# 1,2,단계 디렉토리 구조.트리디렉토리구조
# <오답>3단계 디렉토리 구조
#
# 10. 파일 구성방식 중 ISAM의 물리적인 색인 구성은 디스크의 물리적 특성에 따라 색인을 구성
# 실린더,트랙,마스터
# <오답>볼륨
#
# 12.UNIX시스템에서 파일 보호를 위해 사용하는 방법,read,write,execute등 세가지 접근 유형을 정의하여 제한된 사용자들에게만 접근을 허용, unix의 이러한 파일 보호 방법은 파일 보호 기법 종류중 무엇? 접근제어
#
# 13.보안
# 외부 보안은 불법 침입자나 천재지변으로부터 시스템 보호
# 내부 보안은 하드웨어나 운영체제에 내장된 보안 기능을 토해 신뢰성을 유지하고 시스템을 보호
# 시설 보안은 감지기능을 통해 외부 침입자나 화재 홍수와 같은 천재지변으로부터 보안
# <오답>사용자 인터페이스 보안은 사용자의 신원을 운영체제가 확인하는 절차 없이 불법 침입자침부터 시스템 보호
#
# 14.하드웨어나 운영체제에 내장된 기능으로 포르그램의 신뢰성 잇는 운영과 데이터의 무결성을 보장하기위한 관련 보안? 내부보안
#
# 15.컴퓨터 시스템에서 전송 정보가 오직 인가된 당사자에의해서만 수정될 수 있도록 통제하는 것? 인증
#
# 16.암호법
# DES알고리즘,공용키시스템,RSA알고리즘
# <오답>RISC
#
# 17.데이터 암호화 시스템 중 암호화키와 해독키가 따로 존재하여 암호화키는 공용키로 공개되어 있고 해독키는 개인키로 비밀이 보장되어 잇는 방식? 공개키시스템
#
# 18.공개키 시스템에 대한 설명
# 암호와 해독에 다른 키 사용
# 암호키는 공개되어 누구나 사용
# 해독키는 당사자만
# <오답>키 분매가 비밀키 시스템보다 어렵다
#
# 19.수신자가 메시지 전송 도중에 변경되지 않았음을 확인할 수 있으며, 메시지가 정당한 상대방으로부터 전달된 것임을 확인 하는 기법? 인증교환기법
#
# # 10. 분산처리시스템
# 1.다중처리기 특징
# 자체 계산 능력
# 프로세서나 주변장치 등을 공동으로 사용
# 여러 개의 처리기를 사용하여 신속한 처리 가능
# <오답>각 프로세서들이 여러 개의 기억 장소나 전용 기억 장소를 가진다
#
# 2.처리기를 연결하는 기법중 공유버스기법
# 한 시점에 단지 하나의 전송만 가능
# 버스에 이상이 생기면 전체 시스템에 장애 발생
# 버스의 사용을 위한 경쟁 상태가 발생하여 시스템 성능에 심각한 저해
# <오답>처리기나 기타 장치의 증설 절차 복잡
#
# 3.주/종 처리기 시스템
# 입,출력 연산 담당
# 주프로세서만이 운영체제 수행
# 주프로세서에 문제가 발생하면 전체 시스템 멈춘다
# <오답>주프로세서는 입,출력 위주의 작업 처리
#
# 4.강결합 시스템과 약결합 시스템
# 약결합 시스템은 각각의 시스템이 별도의 운영체제 가진다
# 강결합 시스템은 하나의 운영체제가 모든 처리기와 시스템 하드웨어 제어
# 약결합 시스템은 메시지를 사용하여 상호 통신
# <오답>약결합 시스,템은 하나의 저장장치 공유
#
#
# 5.약결합
# 둘 이상의 독립된 컴퓨터 시스템을 통신 링크 이용하여 연결한 시스템
# 시스템마다 독자적인 운영체제 보유
# 프로세서 간의 통신은 메시지 전달이나 원격 프로시저 호출
# <오답>프로세서 간 통신은 공유 기억 장치 통하여 이루어진다
#
# 6. 분리수행
# 한 프로세서의 장애는 전시스템에 영향을 미치지 않는다
# 프로세서 별 자신만의 파일 및 입,출력 장치를 제어
# 프로세서 별 인터럽트는 독립적 수행
# <오답>하나의 주프로세서와 나머지 종프로세서 구성
#
# 7. 강결합 시스템
# 프로세스간의 통신은 공유 메모리 이용
# 여러 처리기들 간에 하나의 저장장치 공유
# 메모리에 대한 프로세스 간의 경쟁 최소화
# <오답>각 사이트는 자신만의 독립된 운영체제와 주기억 장치
#
# 8.분산 시스템
# 다수의 사용자들이 데이터 공유
# 다수의 사용자들 간에 통신 용이
# 귀중한 장치들이 다수의 사용자들에 의해 공유
# <오답>집중형 시스템에 비해 소프트웨어의 개발 용이
#
#
#
# 9.분산처리 시스템 장점
# 자원공유도향상,처리율향상,신뢰성향상
# <오답>보안성
#
# 10.투명성
# 위치:하드웨어와 소프트웨어의 물리적 위치를 사용자가 알 필요 없다
# 복제:사용자에게 통지할 필요 없이 시스템 안에 파일들과 자원들의 부가적 복사 자유로이
# 병행:다중 사용자들이 자원들을 자동적 공유
# <오답>이주:자원자들이 한곳에서 다른 곳으로 이동하면 자원들의 이름도 자동으로 바뀜
#
# 11.분산시스템 구축
# 자원 공유의 용이성,연산속도향상,신뢰성향상
# <오답>보안성
#
# 12.분산시스템
# 분산된 노드들은 통신 네트워크 이용하여 메시지 주고 받고 정보 교환
# 사용자에게 동적으로 할당할 수 있는 일반적인 자원들이 각 노드 분산
# 사용자는 특정 자원의 물리적 위치를 알지 못하여도 사용
# <오답>시스템 전체의 정책을 결정하는 어떤 통합적인 제어 기능 필요하지 않는다
#
# 13.분산운영체제에서 사용자가 원하는 파일이나 데이터베이스,프린트등의 자원들이 지역 컴퓨터 , 네트워크 내의 다른 원격지 컴퓨터에 존재하더라도 위치에 관계없이 그의 사용 보장? 위치투명성
#
# 14.모든사이트는 하나의 중앙 노드 연결,통신비용저렴,중앙노드과부하시 성능감소,단절
# ->Star connection
#
# 15. 각 사이트는 정확히 다른 두 사이트와 물리적 연결, 정보 전달 방향은 단방향,양방향
# 기본비용은 사이트의 수에 비례, 메시지가 링을 순환할 경우 통신비용증가 ->Ring
#
# 16.컴퓨터 시스템이 중앙 집중 형태에서 분산처리 시스템으로 발전하게 된 이유
# 자원공유,연산속도향상,ㅅ;ㄴ뢰성향상
# <오답>보안기능향상
#
# 17. 컴퓨터 시스템이 중앙 집중 형태에서 분산처리 시스템으로 발전하게 된 이유
# Master에 문제가 발생하면 입/출력 작업 수행할수없다
# 비대칭 구조
# 하나의 처리기를 master로 지정하고 다른 처리기들은 slave처리
# <오답>slave만이 운영체제 수행할 수 있다
#
# 18. 분산 운영체제의 설명
# 시스템 변경을 위한 점진적 확대 용이성
# 고가의 하드웨어에 대한 여러 사용자들간의 공유
# 빠른 응답시간
# <오답>향상된 보안성
#
# 19.UNIX운영체제 특징
# 높은 이식성,계층적 파일시스템,네트워킹 시스템
# <오답>단일 작업용 시스템
#
# 20.UNIX명렁어를 백그라운드로 수행할 때 장점
# 수행중인 명령문이 끝나기 전에 다른 명령문 줄 수 있다
#
# 21. UNIX시스템에서 커널 설명
# UNIX시스템의 중심부 해당
# 프로세스 관리,기억장치 관리등 담당
# 하드웨어 캡슐화
# <오답>사용자와 시스템 간의 인터페이스 제공
#
# 22.유닉스 시스템에서 명령어 해석기로 사용자의 명령어를 인식하여 필요한 프로그램 호출하고 그 명령을 수행하는 기능 담당? 쉘
#
# 23.UNIX에서 사용자와 시스템 간의 인터페이스 담당? SHELl
#
# 24. UNIX시스템에서 사용하는 디렉토리 구조? 트리구조
#
# 25.UNIX파일시스템
# 부트블럭,I-node,슈퍼블록
# <오답>사용자블록
#
# 26.UNIX에서 각 파일에 대한 정보를 기억하고 있는 자료 구조, 파일 소유자의 식별번호,파일크기,파일의 최종 수정시간,파일링크 수 등의 내용 가지는 것/ I-Node
#
# 27. UNIX파일 시스템의 I-node에서 관리하는 정보
# 링크수,만들어진시간,크기
# <오답>파일이 최초로 수정된시간
#
# 28. UNIX에서 새로운 프로그램 수행시키기 위한 시스템 호출?
# EXEC
# 29. UNIX파일의 사용허가 정하는 명령어? CHMOD
#
# 30.자식 프로세스의 하나가 종료될 떄까지 부모 프로세스 임시 중지시키는 유닉시
# WAIT()
#
# 31.파일 내용을 화면에 표시하는 UNIX? CAT
#
# 32.UNIX에서 파일에 대한 엑세스 (읽기,쓰기,실행)권한을 설정하여 사용자에게 제한적인 권한을 주려고 할떄 사용하는 명령어? CHMOD()
#
# 33. UNIX설명
# 트리 구조의 파일 시스템
# 대화식 시분할 운영체제
# 이식성이 높다
# <오답>다중 태스킹 환경이 지원되지 않는다.
#
# 34. UNIX의 셀에 대한 설명
# 명령어 해석기
# 시스템과 사용자 간의 인터페이스 담당
# Bourne shell, C shell등이 있다
# <오답>프로세스,기억장치,입/출력 관리 수행
