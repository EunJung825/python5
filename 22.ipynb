# %% [markdown]
# # 2020년 1회 , 2회 , 3회
#
# ## 1과목
# 데이터베이스설계(물리적단계)
# 해싱-slot
# 버블정렬 -1회전
# SQL언어(제어어-DCL)
# DBMS시스템 필수 기능
# 릴레이션특징
# 네트워크 데이터모델
# 단말노드 개수
# 중위표기방식->전위표기방식
# 뷰(VIEW)
# 정규형-3정규형
# 스키마
# 데이트베이스설계(논리적단계)
# SQL테이블생성
# 데이터베이스 설계 단계 순서
# 로킹
# E-R모델
# 스택 순서
# 비선형구조
# 트리의 차수
# 릴레이션
# 삽입정렬
# SQL명령어
# Backup
# 튜플수
# 정규화
# 힙정렬
# 외부스키마
# 관계해석
# 정렬알고리즘
# 시스템카탈로그
# 원자성
#
# ## 과목
# 보조기억장치 특징
# 버스 논리회로
# ALU위치와 기능
# 인터럽트
# 8진수 연산값
# OP-Code 8비트 생성 명령어의수
# 채널기능
# 비수치적 연산
# 트랩
# 게이트 출력
# Full Adder계산
# 마이크로 오퍼레이션
# 명령어 피연산자 값 상실하는 명령어 형식
# 인스트럭션 종류 판단 상태
# 카운터(PC)
# 캐시메모리
# 논리도-출력단자
# 주기억장치 대역폭
# 레지스터
# DMA
# MAR
# 마이크로 오퍼레이션
# 오류검사코드-Biquinary code
# 부동 소수점 표현 방법
# 폴링
# 2진수 - 코드 변환
# SRAM/DRAM
# JMP X :  PC<-X
# 마스크 비트
# 스테이징
# CAM
# 사이클 훔침
# 누산기
# 명령어 사이클
#
#
#
#
#
#
#
# ## 3과목
# 오류검사
# 코드설계
# 트랜잭션파일
# 자료사전-반복
# 시스템 특성 – 제어성
# 폭포수모형
# 기능적 응집도
# 오류-필사오류
# 턴어라운드 시스템
# 단말
# MTTR계산
# 추출
# 문서화
# 자료결합도
# N-S차트
# 메소드
# 표의숫자코드
# 객체지향시스템-동적모형단계
# 색인순차파일
# 갱신
# 소프트웨어 개발 단계 – 요구분석
# 정보처리 표준 처리 패턴 – 조합
# 시스템 오류 검사 기법 – Echo Check
# 누락오류
# 시스템 기본요소
# 자료사전 – 주석
# 프로세스 설계
# 객체지향 분석 설계
# 동적 모형화
# 시스템 특성 – 제어성
# 럼바우 객체지향 분석 기법- 기능모델링
# 구조적 설계 평가 기준 -응집도 순서
# 자료 흐름도
# 테스트 단계 -인수 테스트
# 코드부여 방법- 연산코드
# 트랜잭션 파일
# 코드설계
# IPT
# 객체지향 언어
#
#
#
#
#
# ## 4과목
# 클라이언트
# SRT스케줄링
# FIFO
# 파일보호기법
# 노화
# RR방식
# 기억장치 할당
# 교착상태
# 파일 디스크립터
# 운영체제 기능
# 선점알고리즘
# 파일시스템
# 시스템호출종류-프로세스제어 명령어
# 분산처리시스템-성형
# 공간 구역성
# 교착상태
# 다중처리기운영체제 – 주/종
# 스레싱
# 분산처리 시스템-목적
# 섹터
# 운영체제
# 스레드
# 강결합,약결합
# 모니터
# 다중처리운영체제-주.종처리기
# 구역성
# 보안
# I-node
# 로더-연결
# 구역성
# 분산처리 시스템
# 프로세스 정의
# 시스템 소프트웨어
#
#
# ## 5과목
# IP - B클래스 주소 범위
# 신호속도
# Li-Fi
# ATM셀
# 유니캐스트
# 가상회선패킷교환
# 광섬유 케이블
# 위성 통신 다중 접속
# 스트림소켓
# 프로토콜
# ARQ
# OSI 7계층 모델 – 물리계층
# 샤논
# QAM
# CSMA/CD
# HDLC프레임구조
# 적응적(Adaptive)AQR
# PCM방식
# Link state방식
# DNS서버 포트번호
# 라우터
# IEEE 802표준규격
# PSK
# 통신속도
# QAM
# LAN토폴로지 형태
# SET
# PCM순서 과정
# OSI 7 계층 -전송계층
# HDLC프레임구조
# Go-back N ARQ
# LAN
# 전이중(Full-Duplex)
# TCP헤더 플래그 비트
# 패킷교환방식
# CODEC
# 전송속도
