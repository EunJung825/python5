# %% [markdown]
# # 5. 시스템 분석 및 설계
# ## 1.시스템 개요
# S/W 개발 절차 -> 요구분석 -설계 - 구현(코딩)- 테스트(시험)-유지보수
# #### 시스템
# 어떤 목적을 위하여 하나 이상의 상호 관련된 요소의 유기적인 결합체
# 종합성
# 목적성
# 자동성
# 제어성
# #### 시스템 개요
# 입력
# 처리
# 출력
# 제어
# 피드백
# #### 시스템 개발 주기
# 조사/분석/설계/구현/테스트/유지보수
#
# ## 2.코드설계
# 코드의기능:배열,분류,식별
# 연상성/확장성
# #### 코드 설계시 유의사항
# 단순성,고유성,표의성,공통성,체계성
# #### 순서코드:일련번호
# 명확한 분류 기준이 없음
# 단순하소 이해하기 쉬움
# #### 구분코드
# 공통성 있는 것끼리 블록으로 구분, 각 블록 내에서 일련 번호를 부여하는 방법
# #### 그룹 분류 코드:대분류,중분류,소분류
# #### 10진코드:도서분류코드
# #### 표의 숫자 코드: 물리적수치(길이,넓이,부피,무게)
# #### 연상코드:가전제품
# #### 코드 오류 종류
# 필사오류:한자리를 잘못기록
# 전위오류좌우 자리를 바꾸어 기록
#
# ## 3.입출력 설계
# #### 입력 설계 순서
# 발생
# 수집
# 매체화
# 투입
# 내용
# #### 입력방식
# 집중 입력 방식
# 턴 어라운드 방식
# 분산 입력 방식
# #### 원시 전표 기입시 고려 사항 : 설문지
# #### 출력 설계 순서
# 내용
# 매체화
# 분배
# 이용
# #### 출력 매체
# com시스템: 처리 결과를 마이크로필름에 기록
#
#
# ## 4. 파일설계
# #### 파일설계순서
# 성격
# 항목
# 특성
# 매체
# 편성법
# #### 파일
# 레코드형식:비블록화고정길이레코드/블록화고정길이레코드/비블록화가변길이레코드/블록화가변길이레코드
# #### 파일의 분류
# 매체/내용/편성 방법에 따른 분류
# #### 순차편성:자기테이프
# #### 색인 순차 편성:자기디스크
# #### 해싱함수
# 충돌가능성
# 계산시간필요
# 시노임
# 검색은 빠르지만 기억공간의 낭비 발생
# #### 리스트 편성: 포인터
# 삽입,삭제 쉬움
# #### 파일 내용에 의한 분류
# 마스터파일:원장
# 트랜잭션 파일:갱신
# 히스토리 파일:복구
# 트레일러 파일: 마스터 파일 끝부분
#
# ## 5. 프로세스설계,처리패턴,오류체크
# #### 프로세스 설계 유의사항
# 신뢰성과 정확성 고료
# 오류 체크 시스템 고려
# #### 입력 단게 오류 체크
# 유효범위체크
# 일괄합계체크
# 균형체크
# 데이터수체크
# 체크디지트체크
# #### 계산 처리 단계 오류 체크
# 불일치 레코드 체크
# 중복 레코드 체크
# 한계 초콰 체크
# #### 처리 패턴
# 변환
# 병합
# 갱신
# 분배
# #### 프로그램 설계서
# 특징: 프로그램의 세부사항을 설계하는 단계
# 포함될 사항: 입,출력설계표,시스템명,코드표,프로세스 흐름도 등
#
# ## 6. 평가,테스트,유지보수,문서화
# 목적:성능과 유용도를 판단
# 방법:만족도 분석 , 정확성과 효율성 분석
# 항목:성능,유연성,기능,신뢰성
# #### 평가>신뢰도측정
# MTBF
# MTTR
# 신뢰도 공식
# 신뢰도 계산 문제
# #### 테스트 종류
# 단위테스트
# 통합테스트
# 시스템테스트
# #### 유지보수
# #### 문서화 목적 및 효과
# 관리의 효율화
# 유연성
# 유지보수
# 혼란방지
# 인계인수작업 용이
#
# ## 7. 구조적 개발 방법론
# #### 소프트웨어 생명주기
# #### 폭포수 모형
# #### 프로토타입 모형
# #### 나선형 모형
# #### 구조적 분석
# #### 자료흐름도
# #### 자료사전
# #### 소단위 명세서
# #### 구조적 설계
# #### 모듈
# #### 결합도
# #### 응집도
# #### N_S CHART
# #### HIPO
# #### IPT
#
# ## 8.객체지향 개발 방법론
# #### 객체,클래스,메시지-개념이해하기
# #### 캡슐화
# #### 상속
# #### 추상화
# #### Booch
# #### 코드와 요돈기법
# #### Rumbaugh
